# %% [markdown]
# ## Ensure that you have relevant data in data_untracked

# %%
import numpy as np
import pandas as pd

from extract_data import extract 
from create_data import create_labels, create_features
# from create_data import create_features

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ___
# ## Section 1. Create Data
# ___

# %% [markdown]
# ### Extract form 4 data if missing

# %%
data_extractor = extract.Data_Extractor()
data_extractor.create_form4()
# Out:
# ========== Required SEC files present ==========

# %%
# Create data labels if missing
label_data_creator =  create_labels.Label_Data_Creator()
label_data_creator.create_labels()
# Out:
# ========== Required labelled files present ==========
# ========== Skip data label creation ==========
# ========== Reading successful ==========

# %%
feature_data_creator = create_features.Feature_Data_Creator()
feature_data_creator.create_features()
# Out:
# === Key file is found. Extracting ===

# %%
feature_data_creator.data
# Out:
#          TRANS_SK      ACCESSION_NUMBER  \
# 0         2529794  0001181431-13-025899
# 1         2529794  0001181431-13-025899
# 2         2529795  0001181431-13-025899
# 3         2529795  0001181431-13-025899
# 4          406837  0000919574-19-000485
# ...           ...                   ...
# 8060960   3335346  0001104659-10-033567
# 8060961   3335346  0001104659-10-033567
# 8060962   3335346  0001104659-10-033567
# 8060963   3335346  0001104659-10-033567
# 8060964   3335346  0001104659-10-033567
#
#                                   SECURITY_TITLE  TRANS_DATE  \
# 0                                   Common Stock  2013-05-03
# 1                                   Common Stock  2013-05-03
# 2                                   Common Stock  2013-05-07
# 3                                   Common Stock  2013-05-07
# 4         Common Stock, par value $.01 per share  2019-01-15
# ...                                          ...         ...
# 8060960  Common Stock, par value $0.01 per share  2010-04-09
# 8060961  Common Stock, par value $0.01 per share  2010-04-09
# 8060962  Common Stock, par value $0.01 per share  2010-04-09
# 8060963  Common Stock, par value $0.01 per share  2010-04-09
# 8060964  Common Stock, par value $0.01 per share  2010-04-09
#
#         DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED  \
# 0                         NaN          S                    0
# 1                         NaN          S                    0
# 2                         NaN          S                    0
# 3                         NaN          S                    0
# 4                         NaN          P                    0
# ...                       ...        ...                  ...
# 8060960                   NaN          S                    0
# 8060961                   NaN          S                    0
# 8060962                   NaN          S                    0
# 8060963                   NaN          S                    0
# 8060964                   NaN          S                    0
#
#         TRANS_TIMELINESS  TRANS_SHARES  TRANS_PRICEPERSHARE  ...  \
# 0                    NaN         736.0                18.50  ...
# 1                    NaN         736.0                18.50  ...
# 2                    NaN        1014.0                18.50  ...
# 3                    NaN        1014.0                18.50  ...
# 4                    NaN       10322.0                 3.04  ...
# ...                  ...           ...                  ...  ...
# 8060960              NaN         199.0                21.92  ...
# 8060961              NaN         199.0                21.92  ...
# 8060962              NaN         199.0                21.92  ...
# 8060963              NaN         199.0                21.92  ...
# 8060964              NaN         199.0                21.92  ...
#
#         trader_mean_car_120_y  trader_mean_volume external_validation  \
# 0                    0.483519          875.000000                   0
# 1                    0.483519          875.000000                   0
# 2                    0.483519          875.000000                   0
# 3                    0.483519          875.000000                   0
# 4                 -125.667747         9254.000000                   0
# ...                       ...                 ...                 ...
# 8060960                   NaN          641.904762                   0
# 8060961                   NaN          641.904762                   0
# 8060962                   NaN          641.904762                   0
# 8060963                   NaN          641.904762                   0
# 8060964                   NaN          641.904762                   0
#
#         snorkel_prob  snorkel_pred Unnamed: 0 js_bin  b_bin jb_bin os_bin
# 0           0.893302             1          0      0      0      0      0
# 1           0.893302             1          1      0      0      0      0
# 2           0.893302             1          0      0      0      0      0
# 3           0.893302             1          1      0      0      0      0
# 4           0.478567             0          2      0      1      0      0
# ...              ...           ...        ...    ...    ...    ...    ...
# 8060960     0.893302             1     778554      0      0      0      0
# 8060961     0.893302             1     778555      0      0      0      0
# 8060962     0.893302             1     778556      0      0      0      0
# 8060963     0.893302             1     778557      0      0      0      0
# 8060964     0.893302             1     778558      0      0      0      0
#
# [8060965 rows x 99 columns]

# %% [markdown]
# ___
# ## Section 2. Modelling, Training and Validation
# ___

# %% [markdown]
# ___
# ## Compare results
# ___
