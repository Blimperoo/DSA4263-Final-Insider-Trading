# %% [markdown]
# ## Ensure that you have relevant data in data_untracked

# %%
import numpy as np
import pandas as pd

from extract_data import extract 
from create_data import create_labels, create_features
# from create_data import create_features

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %% [markdown]
# ___
# ## Section 1. Create Data
# ___

# %% [markdown]
# ### Extract form 4 data if missing

# %%
data_extractor = extract.Data_Extractor()
data_extractor.create_form4()

# %%
# Create data labels if missing
label_data_creator =  create_labels.Label_Data_Creator()
label_data_creator.create_labels()
# Out:
# ========== Required labelled files present ==========
# ========== Skip data label creation ==========
# ========== Reading successful ==========

# %%
feature_data_creator = create_features.Feature_Data_Creator()
feature_data_creator.create_features()
# Out:
# === Footnote Key file is found. Extracting ===
# Rows mismatch after merging, new, old:  8060965 778559
# === Other Features Key file not found, begin creating  ===
# Rows mismatch after merging, new, old:  8060965 778559

# %%
feature_data_creator.data
# Out:
#          TRANS_SK      ACCESSION_NUMBER  \
# 0         2529794  0001181431-13-025899
# 1         2529794  0001181431-13-025899
# 2         2529795  0001181431-13-025899
# 3         2529795  0001181431-13-025899
# 4          406837  0000919574-19-000485
# ...           ...                   ...
# 8111936   3335346  0001104659-10-033567
# 8111937   3335346  0001104659-10-033567
# 8111938   3335346  0001104659-10-033567
# 8111939   3335346  0001104659-10-033567
# 8111940   3335346  0001104659-10-033567
#
#                                   SECURITY_TITLE  TRANS_DATE  \
# 0                                   Common Stock  2013-05-03
# 1                                   Common Stock  2013-05-03
# 2                                   Common Stock  2013-05-07
# 3                                   Common Stock  2013-05-07
# 4         Common Stock, par value $.01 per share  2019-01-15
# ...                                          ...         ...
# 8111936  Common Stock, par value $0.01 per share  2010-04-09
# 8111937  Common Stock, par value $0.01 per share  2010-04-09
# 8111938  Common Stock, par value $0.01 per share  2010-04-09
# 8111939  Common Stock, par value $0.01 per share  2010-04-09
# 8111940  Common Stock, par value $0.01 per share  2010-04-09
#
#         DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED  \
# 0                         NaN          S                    0
# 1                         NaN          S                    0
# 2                         NaN          S                    0
# 3                         NaN          S                    0
# 4                         NaN          P                    0
# ...                       ...        ...                  ...
# 8111936                   NaN          S                    0
# 8111937                   NaN          S                    0
# 8111938                   NaN          S                    0
# 8111939                   NaN          S                    0
# 8111940                   NaN          S                    0
#
#         TRANS_TIMELINESS  TRANS_SHARES  TRANS_PRICEPERSHARE  \
# 0                    NaN         736.0                18.50
# 1                    NaN         736.0                18.50
# 2                    NaN        1014.0                18.50
# 3                    NaN        1014.0                18.50
# 4                    NaN       10322.0                 3.04
# ...                  ...           ...                  ...
# 8111936              NaN         199.0                21.92
# 8111937              NaN         199.0                21.92
# 8111938              NaN         199.0                21.92
# 8111939              NaN         199.0                21.92
# 8111940              NaN         199.0                21.92
#
#         TRANS_ACQUIRED_DISP_CD  SHRS_OWND_FOLWNG_TRANS  \
# 0                            D                  1083.0
# 1                            D                  1083.0
# 2                            D                    69.0
# 3                            D                    69.0
# 4                            A                117817.0
# ...                        ...                     ...
# 8111936                      D                     0.0
# 8111937                      D                     0.0
# 8111938                      D                     0.0
# 8111939                      D                     0.0
# 8111940                      D                     0.0
#
#         DIRECT_INDIRECT_OWNERSHIP NATURE_OF_OWNERSHIP  trans_amt FILING_DATE  \
# 0                               D                 NaN   13616.00  2013-05-07
# 1                               D                 NaN   13616.00  2013-05-07
# 2                               D                 NaN   18759.00  2013-05-07
# 3                               D                 NaN   18759.00  2013-05-07
# 4                               I        See Footnote   31378.88  2019-01-17
# ...                           ...                 ...        ...         ...
# 8111936                         I       See footnotes    4362.08  2010-06-11
# 8111937                         I       See footnotes    4362.08  2010-06-11
# 8111938                         I       See footnotes    4362.08  2010-06-11
# 8111939                         I       See footnotes    4362.08  2010-06-11
# 8111940                         I       See footnotes    4362.08  2010-06-11
#
#         PERIOD_OF_REPORT  ISSUERCIK                  ISSUERNAME  \
# 0             2013-05-03     913165                EXACTECH INC
# 1             2013-05-03     913165                EXACTECH INC
# 2             2013-05-03     913165                EXACTECH INC
# 3             2013-05-03     913165                EXACTECH INC
# 4             2019-01-15     896985  Destination Maternity Corp
# ...                  ...        ...                         ...
# 8111936       2010-03-05    1101169        VIASYSTEMS GROUP INC
# 8111937       2010-03-05    1101169        VIASYSTEMS GROUP INC
# 8111938       2010-03-05    1101169        VIASYSTEMS GROUP INC
# 8111939       2010-03-05    1101169        VIASYSTEMS GROUP INC
# 8111940       2010-03-05    1101169        VIASYSTEMS GROUP INC
#
#         ISSUERTRADINGSYMBOL     RPTOWNERCIK  NUM_RPTOWNERCIK_;  \
# 0                      EXAC         1000032                  1
# 1                      EXAC         1000032                  1
# 2                      EXAC         1000032                  1
# 3                      EXAC         1000032                  1
# 4                      DEST  1000097;898365                  2
# ...                     ...             ...                ...
# 8111936                VIAS    96616;850401                  2
# 8111937                VIAS    96616;850401                  2
# 8111938                VIAS    96616;850401                  2
# 8111939                VIAS    96616;850401                  2
# 8111940                VIAS    96616;850401                  2
#
#                                             RPTOWNERNAME_;  \
# 0                                            BINCH JAMES G
# 1                                            BINCH JAMES G
# 2                                            BINCH JAMES G
# 3                                            BINCH JAMES G
# 4        KINGDON CAPITAL MANAGEMENT, L.L.C.;KINGDON MARK E
# ...                                                    ...
# 8111936              TCW ASSET MANAGEMENT CO;TCW GROUP INC
# 8111937              TCW ASSET MANAGEMENT CO;TCW GROUP INC
# 8111938              TCW ASSET MANAGEMENT CO;TCW GROUP INC
# 8111939              TCW ASSET MANAGEMENT CO;TCW GROUP INC
# 8111940              TCW ASSET MANAGEMENT CO;TCW GROUP INC
#
#                  RPTOWNER_RELATIONSHIP_; RPTOWNER_TITLE_# clean_ticker  \
# 0                               Director              NaN         EXAC
# 1                               Director              NaN         EXAC
# 2                               Director              NaN         EXAC
# 3                               Director              NaN         EXAC
# 4                            Other;Other          nan#nan         DEST
# ...                                  ...              ...          ...
# 8111936  TenPercentOwner;TenPercentOwner          nan#nan         VIAS
# 8111937  TenPercentOwner;TenPercentOwner          nan#nan         VIAS
# 8111938  TenPercentOwner;TenPercentOwner          nan#nan         VIAS
# 8111939  TenPercentOwner;TenPercentOwner          nan#nan         VIAS
# 8111940  TenPercentOwner;TenPercentOwner          nan#nan         VIAS
#
#          is_weird_ticker   PERMNO      date_x      VOL    PRC        RET  \
# 0                  False  83503.0  2013-05-03  24048.0  18.21  -0.011401
# 1                  False  83503.0  2013-05-03  24048.0  18.21  -0.011401
# 2                  False  83503.0  2013-05-07  18702.0  18.41  -0.001085
# 3                  False  83503.0  2013-05-07  18702.0  18.41  -0.001085
# 4                  False  78990.0  2019-01-15  51058.0   3.10   0.016393
# ...                  ...      ...         ...      ...    ...        ...
# 8111936            False  93271.0  2010-04-09  16222.0  21.92   0.001828
# 8111937            False  93271.0  2010-04-09  16222.0  21.92   0.001828
# 8111938            False  93271.0  2010-04-09  16222.0  21.92   0.001828
# 8111939            False  93271.0  2010-04-09  16222.0  21.92   0.001828
# 8111940            False  93271.0  2010-04-09  16222.0  21.92   0.001828
#
#         TICKER      date_y  actual_ret   b_mkt  risk_free_rate  expected_ret  \
# 0         EXAC  2013-05-03   -0.011401  0.8557            0.05     -0.002541
# 1         EXAC  2013-05-03   -0.011401  0.8557            0.05     -0.002541
# 2         EXAC  2013-05-07   -0.001085  0.8619            0.04      0.004589
# 3         EXAC  2013-05-07   -0.001085  0.8619            0.04      0.004589
# 4         DEST  2019-01-15    0.016393  0.6771            2.40      0.786060
# ...        ...         ...         ...     ...             ...           ...
# 8111936   VIAS  2010-04-09         NaN     NaN            0.16           NaN
# 8111937   VIAS  2010-04-09         NaN     NaN            0.16           NaN
# 8111938   VIAS  2010-04-09         NaN     NaN            0.16           NaN
# 8111939   VIAS  2010-04-09         NaN     NaN            0.16           NaN
# 8111940   VIAS  2010-04-09         NaN     NaN            0.16           NaN
#
#          abnormal_ret  CAR_5_before  CAR_5_after  CAR_30_before  CAR_30_after  \
# 0           -0.008860     -0.044129    -0.035446      -0.190171     -0.155710
# 1           -0.008860     -0.044129    -0.035446      -0.190171     -0.155710
# 2           -0.005674     -0.033753    -0.036262      -0.194181     -0.144847
# 3           -0.005674     -0.033753    -0.036262      -0.194181     -0.144847
# 4           -0.769667     -4.448784    -4.804204     -16.118506    -24.111464
# ...               ...           ...          ...            ...           ...
# 8111936           NaN           NaN          NaN            NaN           NaN
# 8111937           NaN           NaN          NaN            NaN           NaN
# 8111938           NaN           NaN          NaN            NaN           NaN
# 8111939           NaN           NaN          NaN            NaN           NaN
# 8111940           NaN           NaN          NaN            NaN           NaN
#
#          CAR_60_before  CAR_60_after  CAR_120_before  CAR_120_after  \
# 0            -0.406155     -0.252463       -0.771921      -0.494860
# 1            -0.406155     -0.252463       -0.771921      -0.494860
# 2            -0.379708     -0.236487       -0.804701      -0.472179
# 3            -0.379708     -0.236487       -0.804701      -0.472179
# 4           -35.896288    -52.494949      -53.086417    -125.473952
# ...                ...           ...             ...            ...
# 8111936            NaN           NaN             NaN            NaN
# 8111937            NaN           NaN             NaN            NaN
# 8111938            NaN           NaN             NaN            NaN
# 8111939            NaN           NaN             NaN            NaN
# 8111940            NaN           NaN             NaN            NaN
#
#         security_category  effective_CAR_30_after  effective_CAR_60_after  \
# 0            common_stock                0.155710                0.252463
# 1            common_stock                0.155710                0.252463
# 2            common_stock                0.144847                0.236487
# 3            common_stock                0.144847                0.236487
# 4            common_stock              -24.111464              -52.494949
# ...                   ...                     ...                     ...
# 8111936      common_stock                     NaN                     NaN
# 8111937      common_stock                     NaN                     NaN
# 8111938      common_stock                     NaN                     NaN
# 8111939      common_stock                     NaN                     NaN
# 8111940      common_stock                     NaN                     NaN
#
#          effective_CAR_120_after  local_score_30  n_local_30  \
# 0                       0.494860        2.441771        18.0
# 1                       0.494860        2.441771        18.0
# 2                       0.472179        2.262109        22.0
# 3                       0.472179        2.262109        22.0
# 4                    -125.473952        0.000000         3.0
# ...                          ...             ...         ...
# 8111936                      NaN             NaN         NaN
# 8111937                      NaN             NaN         NaN
# 8111938                      NaN             NaN         NaN
# 8111939                      NaN             NaN         NaN
# 8111940                      NaN             NaN         NaN
#
#          isolation_raw_30  local_mean_30  local_std_30  n_local_unq_30  \
# 0                    12.0       0.079400      0.132591            12.0
# 1                    12.0       0.079400      0.132591            12.0
# 2                     8.0       0.086792      0.120375            14.0
# 3                     8.0       0.086792      0.120375            14.0
# 4                    27.0            NaN           NaN             0.0
# ...                   ...            ...           ...             ...
# 8111936               NaN            NaN           NaN             NaN
# 8111937               NaN            NaN           NaN             NaN
# 8111938               NaN            NaN           NaN             NaN
# 8111939               NaN            NaN           NaN             NaN
# 8111940               NaN            NaN           NaN             NaN
#
#          local_score_60  n_local_60  isolation_raw_60  local_mean_60  \
# 0              0.524150        33.0               0.0       0.166900
# 1              0.524150        33.0               0.0       0.166900
# 2              0.440569        31.0               0.0       0.162619
# 3              0.440569        31.0               0.0       0.162619
# 4              0.000000         3.0              27.0            NaN
# ...                 ...         ...               ...            ...
# 8111936             NaN         NaN               NaN            NaN
# 8111937             NaN         NaN               NaN            NaN
# 8111938             NaN         NaN               NaN            NaN
# 8111939             NaN         NaN               NaN            NaN
# 8111940             NaN         NaN               NaN            NaN
#
#          local_std_60  n_local_unq_60  local_score_120  n_local_120  \
# 0            0.163242            20.0         0.571961         33.0
# 1            0.163242            20.0         0.571961         33.0
# 2            0.167665            18.0         0.510008         31.0
# 3            0.167665            18.0         0.510008         31.0
# 4                 NaN             0.0         0.000000          3.0
# ...               ...             ...              ...          ...
# 8111936           NaN             NaN              NaN          NaN
# 8111937           NaN             NaN              NaN          NaN
# 8111938           NaN             NaN              NaN          NaN
# 8111939           NaN             NaN              NaN          NaN
# 8111940           NaN             NaN              NaN          NaN
#
#          isolation_raw_120  local_mean_120  local_std_120  n_local_unq_120  \
# 0                      0.0        0.317226       0.310569             20.0
# 1                      0.0        0.317226       0.310569             20.0
# 2                      0.0        0.309444       0.319082             18.0
# 3                      0.0        0.309444       0.319082             18.0
# 4                     27.0             NaN            NaN              0.0
# ...                    ...             ...            ...              ...
# 8111936                NaN             NaN            NaN              NaN
# 8111937                NaN             NaN            NaN              NaN
# 8111938                NaN             NaN            NaN              NaN
# 8111939                NaN             NaN            NaN              NaN
# 8111940                NaN             NaN            NaN              NaN
#
#          isolation_z_30  isolation_z_60  isolation_z_120  anomaly_score_30  \
# 0              0.000000        0.000000         0.000000          0.535917
# 1              0.000000        0.000000         0.000000          0.535917
# 2              0.000000        0.000000         0.000000          0.472506
# 3              0.000000        0.000000         0.000000          0.472506
# 4              0.656073        0.725588         0.931015        -39.930341
# ...                 ...             ...              ...               ...
# 8111936        0.000000        0.000000         0.000000               NaN
# 8111937        0.000000        0.000000         0.000000               NaN
# 8111938        0.000000        0.000000         0.000000               NaN
# 8111939        0.000000        0.000000         0.000000               NaN
# 8111940        0.000000        0.000000         0.000000               NaN
#
#          anomaly_score_60  anomaly_score_120  local_score_30_sig  \
# 0                0.384791           0.777901            0.919958
# 1                0.384791           0.777901            0.919958
# 2                0.340676           0.712994            0.905690
# 3                0.340676           0.712994            0.905690
# 4              -90.584634        -242.292114            0.500000
# ...                   ...                ...                 ...
# 8111936               NaN                NaN            0.500000
# 8111937               NaN                NaN            0.500000
# 8111938               NaN                NaN            0.500000
# 8111939               NaN                NaN            0.500000
# 8111940               NaN                NaN            0.500000
#
#          isolation_z_30_sig  anomaly_score_30_sig  local_score_60_sig  \
# 0                  0.500000              0.448434            0.628118
# 1                  0.500000              0.448434            0.628118
# 2                  0.500000              0.414050            0.608395
# 3                  0.500000              0.414050            0.608395
# 4                  0.658378            -59.978869            0.500000
# ...                     ...                   ...                 ...
# 8111936            0.500000                   NaN            0.500000
# 8111937            0.500000                   NaN            0.500000
# 8111938            0.500000                   NaN            0.500000
# 8111939            0.500000                   NaN            0.500000
# 8111940            0.500000                   NaN            0.500000
#
#          isolation_z_60_sig  anomaly_score_60_sig  local_score_120_sig  \
# 0                  0.500000              0.616559             0.639216
# 1                  0.500000              0.616559             0.639216
# 2                  0.500000              0.570546             0.624808
# 3                  0.500000              0.570546             0.624808
# 4                  0.673836           -131.801924             0.500000
# ...                     ...                   ...                  ...
# 8111936            0.500000                   NaN             0.500000
# 8111937            0.500000                   NaN             0.500000
# 8111938            0.500000                   NaN             0.500000
# 8111939            0.500000                   NaN             0.500000
# 8111940            0.500000                   NaN             0.500000
#
#          isolation_z_120_sig  anomaly_score_120_sig  trader_mean_car_30_x  \
# 0                   0.500000               1.216773              0.150278
# 1                   0.500000               1.216773              0.150278
# 2                   0.500000               1.150800              0.150278
# 3                   0.500000               1.150800              0.150278
# 4                   0.717281            -323.211090            -24.107103
# ...                      ...                    ...                   ...
# 8111936             0.500000                    NaN                   NaN
# 8111937             0.500000                    NaN                   NaN
# 8111938             0.500000                    NaN                   NaN
# 8111939             0.500000                    NaN                   NaN
# 8111940             0.500000                    NaN                   NaN
#
#          trader_mean_car_60_x  trader_mean_car_120_x  trader_mean_car_30_y  \
# 0                    0.244475               0.483519              0.150278
# 1                    0.244475               0.483519              0.150278
# 2                    0.244475               0.483519              0.150278
# 3                    0.244475               0.483519              0.150278
# 4                  -52.817933            -125.667747            -24.107103
# ...                       ...                    ...                   ...
# 8111936                   NaN                    NaN                   NaN
# 8111937                   NaN                    NaN                   NaN
# 8111938                   NaN                    NaN                   NaN
# 8111939                   NaN                    NaN                   NaN
# 8111940                   NaN                    NaN                   NaN
#
#          trader_mean_car_60_y  trader_mean_car_120_y  trader_mean_volume  \
# 0                    0.244475               0.483519          875.000000
# 1                    0.244475               0.483519          875.000000
# 2                    0.244475               0.483519          875.000000
# 3                    0.244475               0.483519          875.000000
# 4                  -52.817933            -125.667747         9254.000000
# ...                       ...                    ...                 ...
# 8111936                   NaN                    NaN          641.904762
# 8111937                   NaN                    NaN          641.904762
# 8111938                   NaN                    NaN          641.904762
# 8111939                   NaN                    NaN          641.904762
# 8111940                   NaN                    NaN          641.904762
#
#          external_validation  snorkel_prob  snorkel_pred  \
# 0                          0      0.893302             1
# 1                          0      0.893302             1
# 2                          0      0.893302             1
# 3                          0      0.893302             1
# 4                          0      0.478567             0
# ...                      ...           ...           ...
# 8111936                    0      0.893302             1
# 8111937                    0      0.893302             1
# 8111938                    0      0.893302             1
# 8111939                    0      0.893302             1
# 8111940                    0      0.893302             1
#
#          net_trading_intensity  net_trading_amt  relative_trade_size_to_self  \
# 0                         -1.0             -1.0                     1.000000
# 1                         -1.0             -1.0                     1.377717
# 2                         -1.0             -1.0                     1.000000
# 3                         -1.0             -1.0                     1.377717
# 4                          1.0              1.0                     1.000000
# ...                        ...              ...                          ...
# 8111936                   -1.0             -1.0                     2.413389
# 8111937                   -1.0             -1.0                     0.495985
# 8111938                   -1.0             -1.0                     2.229909
# 8111939                   -1.0             -1.0                     0.464594
# 8111940                   -1.0             -1.0                     0.299676
#
#          relative_trade_size_to_others
# 0                             0.031093
# 1                             0.054484
# 2                             0.031093
# 3                             0.054484
# 4                             0.198249
# ...                                ...
# 8111936                       0.161881
# 8111937                       0.036035
# 8111938                       0.088090
# 8111939                       0.019541
# 8111940                       0.012267
#
# [8111941 rows x 98 columns]

# %% [markdown]
# ___
# ## Section 2. Modelling, Training and Validation
# ___

# %% [markdown]
# ___
# ## Compare results
# ___
