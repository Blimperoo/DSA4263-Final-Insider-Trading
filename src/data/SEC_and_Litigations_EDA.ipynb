# %% [markdown]
# # SEC Form 4 Data Collation
# Full README.md see here: https://www.sec.gov/files/insider_transactions_readme.pdf

# %%
import pandas as pd

# %%
DATA_FOLDER = "FINAL_RAW_DATA"
LITIGATIONS_DATA_PATH = "infected.csv"
STOCK_PRICE_DATA_PATH = "dataset_summary.csv"

# %%
## Form Submission Main data
submission_data = pd.read_csv(f"{DATA_FOLDER}/SUBMISSION.csv") # ACCESSION_NUMBER is the primary key

## Transaction info for each submission (buy and sell), ACCESSION_NUMBER and (NON)DERIV_TRANS_SK are the primary keys
# One form (i.e. ACCESSION_NUMBER) can have multiple transactions (i.e. *_SK), transactions can be across multiple years, max 30 each 
# Duplicate *_SK keys are for different transactions, and there are max 2 of each duplicate _SK keys
nonderiv_trans_data = pd.read_csv(f"{DATA_FOLDER}/NONDERIV_TRANS.csv")
deriv_trans_data = pd.read_csv(f"{DATA_FOLDER}/DERIV_TRANS.csv")

## Holding info for each submission (what they have - After each transaction..?)
nonderiv_holding_data = pd.read_csv(f"{DATA_FOLDER}/NONDERIV_HOLDING.csv")
deriv_holding_data = pd.read_csv(f"{DATA_FOLDER}/DERIV_HOLDING.csv")

## Name info
reporting_owner_data = pd.read_csv(f"{DATA_FOLDER}/REPORTINGOWNER.csv")
#names_data = pd.read_csv(f"{DATA_FOLDER}/OWNER_SIGNATURE.csv") 

## Additional info, to match with '*_FN' columns in all other datasets based on matching ACCESSION_NUMBER
#footnotes_data = pd.read_csv(f"{DATA_FOLDER}/FOOTNOTES.csv")
# Out:
# /var/folders/qs/szbbnwjs3xqfhs8mjs1pb1xr0000gn/T/ipykernel_51807/2722466562.py:7: DtypeWarning: Columns (7,13,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   nonderiv_trans_data = pd.read_csv(f"{DATA_FOLDER}/NONDERIV_TRANS.csv")
# /var/folders/qs/szbbnwjs3xqfhs8mjs1pb1xr0000gn/T/ipykernel_51807/2722466562.py:8: DtypeWarning: Columns (9,15,19,33,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   deriv_trans_data = pd.read_csv(f"{DATA_FOLDER}/DERIV_TRANS.csv")
# /var/folders/qs/szbbnwjs3xqfhs8mjs1pb1xr0000gn/T/ipykernel_51807/2722466562.py:11: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   nonderiv_holding_data = pd.read_csv(f"{DATA_FOLDER}/NONDERIV_HOLDING.csv")
# /var/folders/qs/szbbnwjs3xqfhs8mjs1pb1xr0000gn/T/ipykernel_51807/2722466562.py:12: DtypeWarning: Columns (17,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   deriv_holding_data = pd.read_csv(f"{DATA_FOLDER}/DERIV_HOLDING.csv")

# %%
# Overview of the data. Drop duplicates and check columns will all null, or all consistent value
dataframes = {
    'submission_data': submission_data,
    'nonderiv_trans_data': nonderiv_trans_data,
    'deriv_trans_data': deriv_trans_data,
    'nonderiv_holding_data': nonderiv_holding_data,
    'deriv_holding_data': deriv_holding_data,
    'reporting_owner_data': reporting_owner_data,
    #'names_data': names_data,
    #'footnotes_data': footnotes_data
}

for name, df in dataframes.items():
    shape = df.shape

    print(f"{name}, {shape}")

    df.drop_duplicates(inplace=True)
    if df.shape[0] != shape[0]:
        print(f"Duplicate rows removed: {shape[0] - df.shape[0]}")
    else:
        print("No duplicate rows")
    null_columns = df.columns[df.isnull().all()]
    print(f"Columns with all null values: {null_columns.tolist()}")
    constant_columns = [col for col in df.columns if df[col].nunique() == 1]
    print(f"Columns with constant values: {constant_columns}")
    print()
# Out:
# submission_data, (2917488, 13)
# No duplicate rows
# Columns with all null values: []
# Columns with constant values: []
#
# nonderiv_trans_data, (4343860, 28)
# No duplicate rows
# Columns with all null values: []
# Columns with constant values: []
#
# deriv_trans_data, (1763084, 42)
# No duplicate rows
# Columns with all null values: ['TRANS_ACQUIRED_DISP_CD_FN']
# Columns with constant values: []
#
# nonderiv_holding_data, (1522788, 14)
# No duplicate rows
# Columns with all null values: ['TRANS_FORM_TYPE_FN']
# Columns with constant values: ['TRANS_FORM_TYPE']
#
# deriv_holding_data, (1000283, 26)
# No duplicate rows
# Columns with all null values: ['TRANS_FORM_TYPE_FN']
# Columns with constant values: ['TRANS_FORM_TYPE']
#
# reporting_owner_data, (3171123, 13)
# No duplicate rows
# Columns with all null values: []
# Columns with constant values: []

# %%
SELECTED_TRANSACTION_COLS = ['ACCESSION_NUMBER', 'SECURITY_TITLE', 'TRANS_DATE', 'DEEMED_EXECUTION_DATE', 'TRANS_CODE', 'EQUITY_SWAP_INVOLVED',
                             'TRANS_TIMELINESS', 'TRANS_SHARES', 'TRANS_PRICEPERSHARE', 'TRANS_ACQUIRED_DISP_CD',
                             'SHRS_OWND_FOLWNG_TRANS', 'DIRECT_INDIRECT_OWNERSHIP', 'NATURE_OF_OWNERSHIP']
# partial primary keys: 'NONDERIV_TRANS_SK', 'DERIV_TRANS_SK'
DERIV_TRANS_UNSURE_COLS = ['CONV_EXERCISE_PRICE', 'EQUITY_SWAP_INVOLVED', 'EXCERCISE_DATE', 'EXPIRATION_DATE', 'UNDLYNG_SEC_SHARES', 'UNDLYNG_SEC_VALUE']

SUBMISSION_COLS = ['ACCESSION_NUMBER', 'FILING_DATE', 'PERIOD_OF_REPORT', 'ISSUERCIK', 'ISSUERNAME', 'ISSUERTRADINGSYMBOL']

REPORTING_OWNER_COLS = ['RPTOWNERCIK', 'RPTOWNERNAME','RPTOWNER_RELATIONSHIP'] # there is also address data and filenumber

# %% [markdown]
# ## Merge Transaction datasets

# %%
nonderiv_trans_data['TRANS_DATE'] = pd.to_datetime(nonderiv_trans_data['TRANS_DATE'], errors='coerce')
deriv_trans_data['TRANS_DATE'] = pd.to_datetime(deriv_trans_data['TRANS_DATE'], errors='coerce')

## Cannot directly concatenate the two dataframes as they have different columns some with identical names
df1 = nonderiv_trans_data[['NONDERIV_TRANS_SK'] + SELECTED_TRANSACTION_COLS].copy().rename(columns={'NONDERIV_TRANS_SK':'TRANS_SK'})
df2 = deriv_trans_data[['DERIV_TRANS_SK'] + SELECTED_TRANSACTION_COLS].copy().rename(columns={'DERIV_TRANS_SK':'TRANS_SK'})
all_transaction_data = pd.concat([df1,df2], axis=0, ignore_index=True).reset_index(drop=True)
print(all_transaction_data.shape)
# Out:
# (6106944, 14)

# %%
# Feature Engineering

## Create transaction amount column
all_transaction_data['trans_amt'] = all_transaction_data['TRANS_SHARES'] * all_transaction_data['TRANS_PRICEPERSHARE']

trans_amt_0 = all_transaction_data[all_transaction_data['trans_amt'] == 0].shape[0]
print(f"There are {trans_amt_0} transactions with amount 0, {trans_amt_0/(all_transaction_data.shape[0])*100:.2f}% of all transactions")
# Out:
# There are 2250213 transactions with amount 0, 36.85% of all transactions

# %%
# To ensure we can drop indirect ownership transactions
all_transaction_data['DIRECT_INDIRECT_OWNERSHIP'].value_counts()
# Out:
# DIRECT_INDIRECT_OWNERSHIP
# D    5257448
# I     849496
# Name: count, dtype: int64

# %%
# Drop irrelevant rows

# Filter out indirect ownership
all_transaction_direct = all_transaction_data[all_transaction_data['DIRECT_INDIRECT_OWNERSHIP'] == 'D']
print(all_transaction_direct.shape)

## Remove transactions with transaction date after 2024 Q4
all_transaction_direct = all_transaction_direct[all_transaction_direct['TRANS_DATE'] < pd.to_datetime('2024-12-31')]
print(all_transaction_direct.shape)

#Filter out rows with NA for transaction date
all_transaction_direct = all_transaction_direct[~(all_transaction_direct['TRANS_DATE'].isna())]
print(all_transaction_direct.shape)

#Split data where trans_amt is 0 and non0, use the non0 data
## e.g. non qualified stock option because is a form of compensation and will have 0 transaction amount
all_transaction_direct_comp = all_transaction_direct[all_transaction_direct['trans_amt'] == 0]
all_transaction_direct = all_transaction_direct[all_transaction_direct['trans_amt'] != 0]

print(all_transaction_direct.shape)
# Out:
# (5257448, 15)
# (5257281, 15)
# (5257281, 15)
# (3191965, 15)

# %%
all_transaction_direct[['TRANS_DATE']].describe() # 1992 - 2024
# Out:
#                           TRANS_DATE
# count                        3191965
# mean   2017-08-03 22:13:11.090628352
# min              1992-11-13 00:00:00
# 25%              2014-01-02 00:00:00
# 50%              2017-05-19 00:00:00
# 75%              2021-02-26 00:00:00
# max              2024-12-30 00:00:00

# %%
all_transaction_direct.head()
# Out:
#    TRANS_SK      ACCESSION_NUMBER SECURITY_TITLE TRANS_DATE  \
# 0   2360796  0001179110-14-011078   Common Stock 2014-06-26
# 1   2360797  0001179110-14-011078   Common Stock 2014-06-26
# 2   2360795  0001179110-14-011078   Common Stock 2014-06-26
# 5   2350316  0001144204-14-040532   Common Stock 2014-05-28
# 6   2350317  0001144204-14-040532   Common Stock 2014-06-27
#
#   DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED TRANS_TIMELINESS  \
# 0                   NaN          S                    0              NaN
# 1                   NaN          S                    0              NaN
# 2                   NaN          S                    0              NaN
# 5                   NaN          A                    0              NaN
# 6                   NaN          A                    0              NaN
#
#    TRANS_SHARES  TRANS_PRICEPERSHARE TRANS_ACQUIRED_DISP_CD  \
# 0        1046.0                28.17                      D
# 1         637.0                28.17                      D
# 2        1278.0                28.17                      D
# 5        1176.0                10.60                      A
# 6        4673.0                10.70                      A
#
#    SHRS_OWND_FOLWNG_TRANS DIRECT_INDIRECT_OWNERSHIP NATURE_OF_OWNERSHIP  \
# 0                 43944.0                         D                 NaN
# 1                 43307.0                         D                 NaN
# 2                 44990.0                         D                 NaN
# 5                 50295.0                         D                 NaN
# 6                 54968.0                         D                 NaN
#
#    trans_amt
# 0   29465.82
# 1   17944.29
# 2   36001.26
# 5   12465.60
# 6   50001.10

# %% [markdown]
# ## Merge with submission data

# %%
submission_data['FILING_DATE'] = pd.to_datetime(submission_data['FILING_DATE'], errors='coerce')
submission_data[['FILING_DATE']].describe() # 2011-2024
# Out:
#                       FILING_DATE
# count                     2917488
# mean   2017-10-29 01:33:20.134912
# min           2011-01-03 00:00:00
# 25%           2014-04-08 00:00:00
# 50%           2017-10-11 00:00:00
# 75%           2021-05-04 00:00:00
# max           2024-12-31 00:00:00

# %%
all_transaction_direct_2 = all_transaction_direct.merge(submission_data[SUBMISSION_COLS], on='ACCESSION_NUMBER', how='left')
all_transaction_direct_2.shape
# Out:
# (3191965, 20)

# %%
all_transaction_direct_2.head(2)
# Out:
#    TRANS_SK      ACCESSION_NUMBER SECURITY_TITLE TRANS_DATE  \
# 0   2360796  0001179110-14-011078   Common Stock 2014-06-26
# 1   2360797  0001179110-14-011078   Common Stock 2014-06-26
#
#   DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED TRANS_TIMELINESS  \
# 0                   NaN          S                    0              NaN
# 1                   NaN          S                    0              NaN
#
#    TRANS_SHARES  TRANS_PRICEPERSHARE TRANS_ACQUIRED_DISP_CD  \
# 0        1046.0                28.17                      D
# 1         637.0                28.17                      D
#
#    SHRS_OWND_FOLWNG_TRANS DIRECT_INDIRECT_OWNERSHIP NATURE_OF_OWNERSHIP  \
# 0                 43944.0                         D                 NaN
# 1                 43307.0                         D                 NaN
#
#    trans_amt FILING_DATE PERIOD_OF_REPORT  ISSUERCIK     ISSUERNAME  \
# 0   29465.82  2014-06-30       2014-06-26     926326  OMNICELL, Inc
# 1   17944.29  2014-06-30       2014-06-26     926326  OMNICELL, Inc
#
#   ISSUERTRADINGSYMBOL
# 0                OMCL
# 1                OMCL

# %% [markdown]
# ## Filter by Kaggle dataset

# %%
stock_price_data = pd.read_csv(f'{DATA_FOLDER}/{STOCK_PRICE_DATA_PATH}')
stock_price_data['symbol'].nunique()
# Out:
# 7786

# %%
# Inner join all_transaction_direct_2 with stock_price_data to get transaction data with avail stock price data
all_transaction_direct_filterd = all_transaction_direct_2.merge(stock_price_data[['symbol']], left_on='ISSUERTRADINGSYMBOL', right_on='symbol', how='inner')
all_transaction_direct_filterd.drop(columns=['symbol'], inplace=True)
all_transaction_direct_filterd.shape
# Out:
# (2534023, 20)

# %% [markdown]
# ## Get Reporting Owner/Owner Signature
# - currently the code joins only 1-1 matching, from all_transaction_direct_filterd to reporting_owner_data by 'ACCESSION_NUMBER'

# %%
# Get overalpping 1-1-1 matching of accession numbers across the three datasets 

## Get unique pk from all_transaction_direct_filterd
accession_num_unique = all_transaction_direct_filterd[['ACCESSION_NUMBER']].drop_duplicates()
print(accession_num_unique.shape)

## get unique pk from reporting_owner_data
matching_reporting_owner = reporting_owner_data[reporting_owner_data['ACCESSION_NUMBER'].isin(accession_num_unique['ACCESSION_NUMBER'])]
matching_rpt_pk = matching_reporting_owner[matching_reporting_owner['ACCESSION_NUMBER'].map(matching_reporting_owner['ACCESSION_NUMBER'].value_counts()) == 1][['ACCESSION_NUMBER']]
print(matching_rpt_pk.shape)

## get final matching subset of pk from matching_reporting_owner
#matching_reporting_owner_names = names_data[names_data['ACCESSION_NUMBER'].isin(matching_rpt_pk['ACCESSION_NUMBER'])]
#matching_rpt_names_pk = matching_reporting_owner_names[matching_reporting_owner_names['ACCESSION_NUMBER'].map(matching_reporting_owner_names['ACCESSION_NUMBER'].value_counts()) == 1][['ACCESSION_NUMBER']]
#print(matching_rpt_names_pk.shape)

print("Final number of unique ACCESSION_NUMBERS with 1-1 matching names,", matching_rpt_pk.shape[0])
# Out:
# (1325908, 1)
# (1312567, 1)
# Final number of unique ACCESSION_NUMBERS with 1-1 matching names, 1312567

# %%
# Merge 1-1 matching data

## filter all_transaction_direct_filterd to get only ACCESSION_NUMBRE in matching_rpt_names_pk
all_transaction_direct_final = all_transaction_direct_filterd[all_transaction_direct_filterd['ACCESSION_NUMBER'].isin(matching_rpt_pk['ACCESSION_NUMBER'])]

## merge with reporting_owener_data 
all_transaction_direct_final = all_transaction_direct_final.merge(reporting_owner_data[['ACCESSION_NUMBER'] + REPORTING_OWNER_COLS], on='ACCESSION_NUMBER', how='left') 

print(all_transaction_direct_final.shape)
all_transaction_direct_final.head()
# Out:
# (2492139, 23)
#    TRANS_SK      ACCESSION_NUMBER SECURITY_TITLE TRANS_DATE  \
# 0   2360796  0001179110-14-011078   Common Stock 2014-06-26
# 1   2360797  0001179110-14-011078   Common Stock 2014-06-26
# 2   2360795  0001179110-14-011078   Common Stock 2014-06-26
# 3   2350316  0001144204-14-040532   Common Stock 2014-05-28
# 4   2350317  0001144204-14-040532   Common Stock 2014-06-27
#
#   DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED TRANS_TIMELINESS  \
# 0                   NaN          S                    0              NaN
# 1                   NaN          S                    0              NaN
# 2                   NaN          S                    0              NaN
# 3                   NaN          A                    0              NaN
# 4                   NaN          A                    0              NaN
#
#    TRANS_SHARES  TRANS_PRICEPERSHARE TRANS_ACQUIRED_DISP_CD  \
# 0        1046.0                28.17                      D
# 1         637.0                28.17                      D
# 2        1278.0                28.17                      D
# 3        1176.0                10.60                      A
# 4        4673.0                10.70                      A
#
#    SHRS_OWND_FOLWNG_TRANS DIRECT_INDIRECT_OWNERSHIP NATURE_OF_OWNERSHIP  \
# 0                 43944.0                         D                 NaN
# 1                 43307.0                         D                 NaN
# 2                 44990.0                         D                 NaN
# 3                 50295.0                         D                 NaN
# 4                 54968.0                         D                 NaN
#
#    trans_amt FILING_DATE PERIOD_OF_REPORT  ISSUERCIK           ISSUERNAME  \
# 0   29465.82  2014-06-30       2014-06-26     926326        OMNICELL, Inc
# 1   17944.29  2014-06-30       2014-06-26     926326        OMNICELL, Inc
# 2   36001.26  2014-06-30       2014-06-26     926326        OMNICELL, Inc
# 3   12465.60  2014-06-30       2014-05-28    1474464  New York REIT, Inc.
# 4   50001.10  2014-06-30       2014-05-28    1474464  New York REIT, Inc.
#
#   ISSUERTRADINGSYMBOL  RPTOWNERCIK            RPTOWNERNAME  \
# 0                OMCL      1453971  Ortigas-Wedekind Marga
# 1                OMCL      1453971  Ortigas-Wedekind Marga
# 2                OMCL      1453971  Ortigas-Wedekind Marga
# 3                NYRT      1545007         Bowman Scott J.
# 4                NYRT      1545007         Bowman Scott J.
#
#   RPTOWNER_RELATIONSHIP
# 0               Officer
# 1               Officer
# 2               Officer
# 3              Director
# 4              Director

# %% [markdown]
# # Further Data Exploration and Cleaning (WIP)

# %%
pd.set_option('display.max_columns', None)
all_transaction_direct_final[['trans_amt']].describe()
# Out:
#           trans_amt
# count  2.217795e+06
# mean   2.890148e+09
# std    2.734796e+12
# min    1.000000e-02
# 25%    1.339303e+04
# 50%    6.120800e+04
# 75%    2.555155e+05
# max    4.000000e+15

# %%
for i in list(deriv_holding_data.columns):
    print(i)
# Out:
# ACCESSION_NUMBER
# DERIV_HOLDING_SK
# SECURITY_TITLE
# SECURITY_TITLE_FN
# CONV_EXERCISE_PRICE
# CONV_EXERCISE_PRICE_FN
# TRANS_FORM_TYPE
# TRANS_FORM_TYPE_FN
# EXERCISE_DATE
# EXERCISE_DATE_FN
# EXPIRATION_DATE
# EXPIRATION_DATE_FN
# UNDLYNG_SEC_TITLE
# UNDLYNG_SEC_TITLE_FN
# UNDLYNG_SEC_SHARES
# UNDLYNG_SEC_SHARES_FN
# UNDLYNG_SEC_VALUE
# UNDLYNG_SEC_VALUE_FN
# SHRS_OWND_FOLWNG_TRANS
# SHRS_OWND_FOLWNG_TRANS_FN
# VALU_OWND_FOLWNG_TRANS
# VALU_OWND_FOLWNG_TRANS_FN
# DIRECT_INDIRECT_OWNERSHIP
# DIRECT_INDIRECT_OWNERSHIP_FN
# NATURE_OF_OWNERSHIP
# NATURE_OF_OWNERSHIP_FN

# %% [markdown]
# # Getting subset of Data for Caitlyn's network analysis

# %%
# with TRANS_DATE: 2342363, without: 365605, without ISSUERNAME: 356387, without 'ISSUERCIK': 354851
unique_df = all_transaction_direct_final[['RPTOWNERNAME', 'RPTOWNERCIK', 'ISSUERTRADINGSYMBOL']].drop_duplicates()
unique_dates_df = all_transaction_direct_final[['TRANS_DATE', 'RPTOWNERNAME', 'RPTOWNERCIK', 'ISSUERTRADINGSYMBOL']].drop_duplicates()

# %%
all_transaction_direct_final['RPTOWNERNAME'].isna().sum()
# Out:
# 949

# %%
all_transaction_direct_final[all_transaction_direct_final['RPTOWNERNAME'].isna()]
# Out:
#          TRANS_SK      ACCESSION_NUMBER                        SECURITY_TITLE  \
# 153750     640684  0001209191-20-065121                          Common Stock
# 153751     640683  0001209191-20-065121                          Common Stock
# 153752     640688  0001209191-20-065121                          Common Stock
# 153753     640687  0001209191-20-065121                          Common Stock
# 154073     632980  0001639825-20-000223                  Class A Common Stock
# ...           ...                   ...                                   ...
# 2473947   2225569  0001482512-22-000029                            LTIP Units
# 2474073   2223970  0001209191-22-000134  Deferred Compensation Notional Units
# 2474097   2223928  0000802681-22-000008                         Phantom Stock
# 2474098   2223927  0000802681-22-000008                         Phantom Stock
# 2474100   2224126  0000715072-22-000011                         Phantom Stock
#
#         TRANS_DATE DEEMED_EXECUTION_DATE TRANS_CODE EQUITY_SWAP_INVOLVED  \
# 153750  2020-12-21                   NaN          S                    0
# 153751  2020-12-21                   NaN          M                    0
# 153752  2020-12-22                   NaN          S                    0
# 153753  2020-12-22                   NaN          M                    0
# 154073  2020-12-22                   NaN          S                    0
# ...            ...                   ...        ...                  ...
# 2473947 2021-12-29                   NaN          A                    0
# 2474073 2021-12-31                   NaN          A                    0
# 2474097 2021-12-31                   NaN          M                    0
# 2474098 2021-12-31                   NaN          M                    0
# 2474100 2021-12-31                   NaN          A                    0
#
#         TRANS_TIMELINESS  TRANS_SHARES  TRANS_PRICEPERSHARE  \
# 153750               NaN        200.00                35.01
# 153751               NaN        200.00                 4.32
# 153752               NaN       2268.00                35.05
# 153753               NaN       2268.00                 4.32
# 154073               NaN      58045.00               156.79
# ...                  ...           ...                  ...
# 2473947              NaN      20259.00                  NaN
# 2474073              NaN        285.00               103.79
# 2474097              NaN      11549.00                  NaN
# 2474098              NaN      27279.00                  NaN
# 2474100              NaN        428.61                38.50
#
#         TRANS_ACQUIRED_DISP_CD  SHRS_OWND_FOLWNG_TRANS  \
# 153750                       D                 3813.00
# 153751                       A                 4013.00
# 153752                       D                 3813.00
# 153753                       A                 6081.00
# 154073                       D                56213.00
# ...                        ...                     ...
# 2473947                      A                90328.00
# 2474073                      A                 1528.00
# 2474097                      D                    0.00
# 2474098                      D                    0.00
# 2474100                      A                 4171.31
#
#         DIRECT_INDIRECT_OWNERSHIP  \
# 153750                          D
# 153751                          D
# 153752                          D
# 153753                          D
# 154073                          D
# ...                           ...
# 2473947                         D
# 2474073                         D
# 2474097                         D
# 2474098                         D
# 2474100                         D
#
#                                        NATURE_OF_OWNERSHIP    trans_amt  \
# 153750   By The Praveen P. Tipirneni Irrevocable Trust ...     7002.000
# 153751   By The Praveen P. Tipirneni Irrevocable Trust ...      864.000
# 153752                                                 NaN    79493.400
# 153753                                                 NaN     9797.760
# 154073                                                 NaN  9100875.550
# ...                                                    ...          ...
# 2473947                                                NaN          NaN
# 2474073                                                NaN    29580.150
# 2474097                                                NaN          NaN
# 2474098                                                NaN          NaN
# 2474100                                                NaN    16501.485
#
#         FILING_DATE PERIOD_OF_REPORT  ISSUERCIK ISSUERNAME  \
# 153750   2020-12-23       2020-12-21    1679363        NaN
# 153751   2020-12-23       2020-12-21    1679363        NaN
# 153752   2020-12-23       2020-12-21    1679363        NaN
# 153753   2020-12-23       2020-12-21    1679363        NaN
# 154073   2020-12-23       2020-12-22    1639825        NaN
# ...             ...              ...        ...        ...
# 2473947  2022-01-03       2021-12-29    1482512        NaN
# 2474073  2022-01-03       2021-12-31     798354        NaN
# 2474097  2022-01-03       2021-12-31     802681        NaN
# 2474098  2022-01-03       2021-12-31     802681        NaN
# 2474100  2022-01-03       2021-12-31     715072        NaN
#
#         ISSUERTRADINGSYMBOL  RPTOWNERCIK RPTOWNERNAME RPTOWNER_RELATIONSHIP
# 153750                 MORF      1779978          NaN      Director,Officer
# 153751                 MORF      1779978          NaN      Director,Officer
# 153752                 MORF      1779978          NaN      Director,Officer
# 153753                 MORF      1779978          NaN      Director,Officer
# 154073                 PTON      1788276          NaN               Officer
# ...                     ...          ...          ...                   ...
# 2473947                 HPP      1652508          NaN               Officer
# 2474073                FISV      1199930          NaN              Director
# 2474097                BMTC      1357854          NaN              Director
# 2474098                BMTC      1357854          NaN              Director
# 2474100                RNST      1741547          NaN              Director
#
# [949 rows x 23 columns]

# %%
#unique_df.to_csv(f'{DATA_FOLDER}/rptowner_trade.csv', index=False)
#unique_dates_df.to_csv(f'{DATA_FOLDER}/rptowner_trade_with_date.csv', index=False)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Exploring transactions and holdings data

# %%
# Find overlapping ACCESSION_NUMBER values for nonderiv data
nonderv_holding_n = nonderiv_holding_data['ACCESSION_NUMBER'].nunique()
nonderv_trans_n = nonderiv_trans_data['ACCESSION_NUMBER'].nunique()
print(f"Unique ACCESSION_NUMBER for holdings: {nonderv_holding_n}, for transactions: {nonderv_trans_n}")

nonderiv_overlap_values = set(nonderiv_holding_data['ACCESSION_NUMBER']) & set(nonderiv_trans_data['ACCESSION_NUMBER'])
if nonderiv_overlap_values:
    print("Overlapping ACCESSION_NUMBER values found:", len(nonderiv_overlap_values), round(len(nonderiv_overlap_values) / min((nonderv_trans_n, nonderv_holding_n)), 2))
else:
    print("No overlap found.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Find overlapping ACCESSION_NUMBER values for nonderiv data
# ----> 2 nonderv_holding_n = nonderiv_holding_data['ACCESSION_NUMBER'].nunique()
#       3 nonderv_trans_n = nonderiv_trans_data['ACCESSION_NUMBER'].nunique()
#       4 print(f"Unique ACCESSION_NUMBER for holdings: {nonderv_holding_n}, for transactions: {nonderv_trans_n}")
#
# NameError: name 'nonderiv_holding_data' is not defined

# %%
# Find overlapping ACCESSION_NUMBER values for deriv data
derv_holding_n = deriv_holding_data['ACCESSION_NUMBER'].nunique()
derv_trans_n = deriv_trans_data['ACCESSION_NUMBER'].nunique()
print(f"Unique ACCESSION_NUMBER for holdings: {derv_holding_n}, for transactions: {derv_trans_n}")

deriv_overlap_values = set(deriv_holding_data['ACCESSION_NUMBER']) & set(deriv_trans_data['ACCESSION_NUMBER'])
if deriv_overlap_values:
    print("Overlapping ACCESSION_NUMBER values found:", len(deriv_overlap_values), round(len(deriv_overlap_values) / min((derv_trans_n, derv_holding_n)), 2))
else:
    print("No overlap found.")
# Out:
# Unique ACCESSION_NUMBER for holdings: 246962, for transactions: 1107281
# Overlapping ACCESSION_NUMBER values found: 83827 0.34

# %% [markdown]
# ### Case: Overlapping ACCESSION_NUMBER for deriv transactions and holidngs
# 1. '0001062993-24-014375', 1 deriv transaction, 8 holdings, including varying values of 'SHRS_OWND_FOLWNG_TRANS' for different stocks, but no date of transaction
# 2. '0001654954-19-000382', 1 deriv transaction, 2 holdings, varying 'SHRS_OWND_FOLWNG_TRANS' for same stocks, also no date
# 3. '0001209191-11-009901', 1 deriv transaction, 5 holdings, varying 'SHRS_OWND_FOLWNG_TRANS' for 1 different and 4 same stocks, some have non-null EXERCISE_DATE
# 4. '0001437749-21-019709',
# 5. '0001181431-11-003532',
# etc
#
# * Note that nonderiv holdings have a different schema compared to deriv holdings

# %%
ACCESSION_NUMBER_TEST = '0001209191-11-009901'

# %%
deriv_trans_data[deriv_trans_data['ACCESSION_NUMBER']== ACCESSION_NUMBER_TEST]
# Out:
#              ACCESSION_NUMBER  DERIV_TRANS_SK SECURITY_TITLE  \
# 1020924  0001209191-11-009901         1323168   Stock Option
#
#         SECURITY_TITLE_FN  CONV_EXERCISE_PRICE CONV_EXERCISE_PRICE_FN  \
# 1020924               NaN                 4.52                    NaN
#
#         TRANS_DATE TRANS_DATE_FN DEEMED_EXECUTION_DATE  \
# 1020924 2011-02-11           NaN                   NaN
#
#         DEEMED_EXECUTION_DATE_FN  ...  UNDLYNG_SEC_VALUE UNDLYNG_SEC_VALUE_FN  \
# 1020924                      NaN  ...                NaN                  NaN
#
#         SHRS_OWND_FOLWNG_TRANS SHRS_OWND_FOLWNG_TRANS_FN  \
# 1020924                    0.0                       NaN
#
#         VALU_OWND_FOLWNG_TRANS VALU_OWND_FOLWNG_TRANS_FN  \
# 1020924                    NaN                       NaN
#
#          DIRECT_INDIRECT_OWNERSHIP DIRECT_INDIRECT_OWNERSHIP_FN  \
# 1020924                          D                          NaN
#
#          NATURE_OF_OWNERSHIP NATURE_OF_OWNERSHIP_FN
# 1020924                  NaN                    NaN
#
# [1 rows x 42 columns]

# %%
deriv_holding_data[deriv_holding_data['ACCESSION_NUMBER']== ACCESSION_NUMBER_TEST]
# Out:
#             ACCESSION_NUMBER  DERIV_HOLDING_SK       SECURITY_TITLE  \
# 567018  0001209191-11-009901            810244  Phantom Stock Units
# 567019  0001209191-11-009901            810245         Stock Option
# 567020  0001209191-11-009901            810248         Stock Option
# 567021  0001209191-11-009901            810247         Stock Option
# 567022  0001209191-11-009901            810246         Stock Option
#
#        SECURITY_TITLE_FN  CONV_EXERCISE_PRICE CONV_EXERCISE_PRICE_FN  \
# 567018               NaN                 0.00                    NaN
# 567019               NaN                 3.70                    NaN
# 567020               NaN                13.10                    NaN
# 567021               NaN                11.40                    NaN
# 567022               NaN                 4.37                    NaN
#
#         TRANS_FORM_TYPE  TRANS_FORM_TYPE_FN EXERCISE_DATE EXERCISE_DATE_FN  \
# 567018              NaN                 NaN           NaN               F4
# 567019              NaN                 NaN    2002-08-11              NaN
# 567020              NaN                 NaN           NaN               F6
# 567021              NaN                 NaN           NaN               F5
# 567022              NaN                 NaN    2003-08-11              NaN
#
#         ... UNDLYNG_SEC_VALUE UNDLYNG_SEC_VALUE_FN SHRS_OWND_FOLWNG_TRANS  \
# 567018  ...               NaN                  NaN                1688.63
# 567019  ...               NaN                  NaN               30000.00
# 567020  ...               NaN                  NaN               15000.00
# 567021  ...               NaN                  NaN               30000.00
# 567022  ...               NaN                  NaN               36000.00
#
#        SHRS_OWND_FOLWNG_TRANS_FN  VALU_OWND_FOLWNG_TRANS  \
# 567018                       NaN                     NaN
# 567019                       NaN                     NaN
# 567020                       NaN                     NaN
# 567021                       NaN                     NaN
# 567022                       NaN                     NaN
#
#        VALU_OWND_FOLWNG_TRANS_FN  DIRECT_INDIRECT_OWNERSHIP  \
# 567018                       NaN                          D
# 567019                       NaN                          D
# 567020                       NaN                          D
# 567021                       NaN                          D
# 567022                       NaN                          D
#
#        DIRECT_INDIRECT_OWNERSHIP_FN  NATURE_OF_OWNERSHIP  \
# 567018                          NaN                  NaN
# 567019                          NaN                  NaN
# 567020                          NaN                  NaN
# 567021                          NaN                  NaN
# 567022                          NaN                  NaN
#
#        NATURE_OF_OWNERSHIP_FN
# 567018                    NaN
# 567019                    NaN
# 567020                    NaN
# 567021                    NaN
# 567022                    NaN
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Exploring Name Info (1 submission with multiple reporting owners)
# * 79206 have more than one reporting owner
# * highest number of reporting owners is 10, because no more than 10 reporting persons can file any one Form 4 (see 2 cells below)
#
#
# Why is the RPTOWNERNAME so weird?
#
# * Reccomendation: maybe we want to compile the names into 1 tuple, for each accession number?

# %%
submission_data['ISSUERCIK'].nunique() # there are issuerick with multiple issuernames
# Out:
# 14185

# %%
(reporting_owner_data['ACCESSION_NUMBER'].value_counts() == 1).sum() # 0
# Out:
# 2838282

# %%
reporting_owner_data['ACCESSION_NUMBER'].value_counts() > 1
# Out:
# ACCESSION_NUMBER
# 0001209191-21-007755     True
# 0001104659-23-051309     True
# 0001209191-15-052568     True
# 0001571049-14-000053     True
# 0001420295-17-000002     True
#                         ...
# 0001415889-24-010973    False
# 0001349334-24-000008    False
# 0001104659-24-048332    False
# 0001209191-24-005317    False
# 0001437749-20-014299    False
# Name: count, Length: 2917488, dtype: bool

# %%
# See remarks for disclaimer about reporting persons
submission_data[submission_data['ACCESSION_NUMBER'] == '0001209191-21-007755']
# Out:
#              ACCESSION_NUMBER FILING_DATE PERIOD_OF_REPORT DATE_OF_ORIG_SUB  \
# 2409946  0001209191-21-007755  2021-02-04       2021-02-02              NaN
#
#          NO_SECURITIES_OWNED NOT_SUBJECT_SEC16  FORM3_HOLDINGS_REPORTED  \
# 2409946                  NaN                 0                      NaN
#
#          FORM4_TRANS_REPORTED DOCUMENT_TYPE  ISSUERCIK  \
# 2409946                   NaN             4    1794515
#
#                          ISSUERNAME ISSUERTRADINGSYMBOL  \
# 2409946  ZoomInfo Technologies Inc.                  ZI
#
#                                                                                                                                                                                         REMARKS
# 2409946  Because no more than 10 reporting persons can file any one Form 4 through the Securities and Exchange Commission's EDGAR system, Atlantic & Pacific VII-B has filed a separate Form 4.

# %%
reporting_owner_data[reporting_owner_data['ACCESSION_NUMBER'] == '0001209191-21-007755']
# Out:
#              ACCESSION_NUMBER  RPTOWNERCIK  \
# 2604188  0001209191-21-007755      1812579
# 2604189  0001209191-21-007755      1812606
# 2604190  0001209191-21-007755      1034569
# 2604191  0001209191-21-007755      1609539
# 2604192  0001209191-21-007755      1812605
# 2604193  0001209191-21-007755      1609553
# 2604194  0001209191-21-007755      1609536
# 2604195  0001209191-21-007755      1578035
# 2604196  0001209191-21-007755      1548681
# 2604197  0001209191-21-007755      1609557
#
#                                         RPTOWNERNAME  \
# 2604188  TA AP VII-B DO Subsidiary Partnership, L.P.
# 2604189                        TA XI DO AIV II, L.P.
# 2604190                          TA ASSOCIATES, L.P.
# 2604191                        TA XI DO Feeder, L.P.
# 2604192                   TA SDF III DO AIV II, L.P.
# 2604193                      TA SDF III DO AIV, L.P.
# 2604194                           TA XI DO AIV, L.P.
# 2604195                        TA INVESTORS IV, L.P.
# 2604196             TA Atlantic & Pacific VII-A L.P.
# 2604197                   TA SDF III DO Feeder, L.P.
#
#             RPTOWNER_RELATIONSHIP RPTOWNER_TITLE RPTOWNER_TXT  \
# 2604188  Director,TenPercentOwner            NaN          NaN
# 2604189  Director,TenPercentOwner            NaN          NaN
# 2604190  Director,TenPercentOwner            NaN          NaN
# 2604191  Director,TenPercentOwner            NaN          NaN
# 2604192  Director,TenPercentOwner            NaN          NaN
# 2604193  Director,TenPercentOwner            NaN          NaN
# 2604194  Director,TenPercentOwner            NaN          NaN
# 2604195  Director,TenPercentOwner            NaN          NaN
# 2604196  Director,TenPercentOwner            NaN          NaN
# 2604197  Director,TenPercentOwner            NaN          NaN
#
#              RPTOWNER_STREET1 RPTOWNER_STREET2 RPTOWNER_CITY RPTOWNER_STATE  \
# 2604188  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604189  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604190  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604191  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604192  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604193  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604194  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604195  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604196  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
# 2604197  200 CLARENDON STREET       56TH FLOOR        BOSTON             MA
#
#         RPTOWNER_ZIPCODE RPTOWNER_STATE_DESC
# 2604188            02116                 NaN
# 2604189            02116                 NaN
# 2604190            02116                 NaN
# 2604191            02116                 NaN
# 2604192            02116                 NaN
# 2604193            02116                 NaN
# 2604194            02116                 NaN
# 2604195            02116                 NaN
# 2604196            02116                 NaN
# 2604197            02116                 NaN

# %%
pd.set_option('display.max_colwidth', None)
names_data[names_data['ACCESSION_NUMBER'] == '0001209191-21-007755']
# seems like OWNERSIGNATURENAME requires .split(',') to extract alias used in Reporting owner name
# Out:
#              ACCESSION_NUMBER  \
# 2561362  0001209191-21-007755
# 2561363  0001209191-21-007755
# 2561364  0001209191-21-007755
# 2561365  0001209191-21-007755
# 2561366  0001209191-21-007755
# 2561367  0001209191-21-007755
# 2561368  0001209191-21-007755
# 2561369  0001209191-21-007755
# 2561370  0001209191-21-007755
# 2561371  0001209191-21-007755
#
#                                                                                                                                                                                                                    OWNERSIGNATURENAME
# 2561362                               TA SDF III DO AIV, L.P., by TA Associates, SDF III GP L.P., its General Partner, by TA Associates, L.P., its General Partner, by Jeffrey C. Hadden, its, General Counsel, /s/ Jeffrey C. Hadden
# 2561363                                         TA XI DO AIV, L.P., by TA Associates XI GP, L.P., its General Partner, by TA Associates, L.P., its General, Partner, by Jeffrey C. Hadden, its General Counsel, /s/ Jeffrey C. Hadden
# 2561364                                                                                                                                        TA Associates, L.P., by Jeffrey C. Hadden, its, General Counsel, /s/ Jeffrey C. Hadden
# 2561365                       TA Atlantic & Pacific VII-A L.P., by TA Associates AP, VII GP L.P., its General Partner, by TA Associates, L.P., its General Partner, by Jeffrey C. Hadden, its, General Counsel, /s/ Jeffrey C. Hadden
# 2561366                                                                                         TA Investors IV, L.P., by TA Associates, L.P., its General Partner, by Jeffrey C. Hadden, its, General Counsel, /s/ Jeffrey C. Hadden
# 2561367                           TA SDF III DO AIV II, L.P., by TA Associates SDF, III GP, L.P., its General Partner, by TA Associates, L.P., its General Partner, by Jeffrey C. Hadden, its General, Counsel, /s/ Jeffrey C. Hadden
# 2561368                                       TA XI DO AIV II, L.P., by TA Associates XI GP, L.P, its General Partner, by TA Associates, L.P., its General, Partner, by Jeffrey C. Hadden, its General Counsel, /s/ Jeffrey C. Hadden
# 2561369  TA Associates AP VII-B DO Subsidiary Partnership, L.P., by TA Associates AP VII GP L.P., its General Partner, by TA Associates, L.P., its General Partner, by Jeffrey C., Hadden, its General Counsel, /s/ Jeffrey C. Hadden
# 2561370                             TA SDF III DO Feeder, L.P., by TA Associates SDF III GP L.P., its General Partner, by TA Associates, L.P., its General Partner, by Jeffrey C., Hadden, its General Counsel, /s/ Jeffrey C. Hadden
# 2561371                                          TA XI DO Feeder, L.P., by TA Associates XI GP L.P., its General Partner, by TA Associates, L.P., its General Partner, Jeffrey C. Hadden, its, General Counsel, /s/ Jeffrey C. Hadden

# %%
reporting_owner_data[reporting_owner_data['ACCESSION_NUMBER'] == '0001437749-20-014299']# '0001415889-24-010973']#'0001571049-14-000053']
# Out:
#              ACCESSION_NUMBER  RPTOWNERCIK         RPTOWNERNAME  \
# 3171122  0001437749-20-014299      1815956  Hoffman Matthew Leo
#
#         RPTOWNER_RELATIONSHIP           RPTOWNER_TITLE RPTOWNER_TXT  \
# 3171122               Officer  Chief Financial Officer          NaN
#
#                    RPTOWNER_STREET1                     RPTOWNER_STREET2  \
# 3171122  C/O THE CORETEC GROUP INC.  6804 SOUTH CANTON AVENUE, SUITE 150
#
#         RPTOWNER_CITY RPTOWNER_STATE RPTOWNER_ZIPCODE RPTOWNER_STATE_DESC
# 3171122         TULSA             OK            74136                 NaN

# %%
pd.set_option('display.max_colwidth', None)
names_data[names_data['ACCESSION_NUMBER'] == '0001437749-20-014299']#'0001415889-24-010973']#'0001571049-14-000053']
# Out:
#              ACCESSION_NUMBER   OWNERSIGNATURENAME
# 3119137  0001437749-20-014299  /s/ Matthew Hoffman

# %%
names_data[names_data['OWNERSIGNATURENAME']=='/s/ Harry You']
# Out:
#              ACCESSION_NUMBER OWNERSIGNATURENAME
# 2507155  0000899243-21-014301      /s/ Harry You

# %% [markdown]
# # Testing Litigation Data

# %%
data_litigations = pd.read_csv(f"{DATA_FOLDER}/{LITIGATIONS_DATA_PATH}")

# %%
data_litigations[['yr']].describe() # 1996 - 2017
# Out:
#                 yr
# count  1222.000000
# mean   2006.533552
# std       6.041633
# min    1996.000000
# 25%    2002.000000
# 50%    2007.000000
# 75%    2011.000000
# max    2017.000000

# %%
pd.set_option('display.max_colwidth', None)
data_litigations.tail(2)
# Out:
#       Unnamed: 0  lt_no    yr  \
# 1220        7977  24012  2017
# 1221        7980  24015  2017
#
#                                                                                                                  title  \
# 1220                                    Therapist Settles Charges of Insider Trading Ahead of Acquisition Announcement
# 1221  SEC Charges Former Employee and Friend with Insider Trading in Securities of International Rectifier Corporation
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      lt  \
# 1220                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [A Seattle-based therapist has agreed to settle SEC charges that he traded in the stock of zulily, Inc   Zulily  based on information he learned from a Zulily employee during confidential counseling sessions , The SECs complaint alleges that, in July 2015, during counseling sessions, the Zulily employee told Kenneth Peer that Zulily was going to be acquired by Liberty Interactive, a media holding company On three occasions between July 21, 2015 and August 10, 2015, after counseling sessions with the Zulily employee, Peer purchased a total of over $28,000 of Zulily stock The complaint alleges that, before the market opened on August 17, 2015, Zulily announced that it had agreed to be acquired by Liberty Interactive in a tender offer By the end of trading that day, Zulilys stock allegedly had risen by 49%, with nearly 15 times the stocks average daily trading volume Shortly after the acquisition was announced, Peer allegedly sold all of his Zulily shares for illegal profits of approximately $10,000 , The SECs complaint charges Peer with violating Sections 10 b  and 14 e  of the Securities Exchange Act of 1934 and Rules 10b-5 and 14e-3 thereunder Without admitting or denying the SECs allegations, Peer agreed to disgorge $10,227 73 plus interest of $811 80 and pay a $10,227 73 penalty, for a total of $21,267 26 Peer also agreed to be enjoined from further violations of the charged provisions , The SECs investigation was conducted by Alice Liu Jensen and supervised by Steven D  Buchholz, both of the Market Abuse Unit in the San Francisco Regional Office The SEC appreciates the assistance of FINRA in this matter , <img alt border0 height9 srcimagesarrowright_dkblue gif width10><a hreflitigationcomplaints2017comp24012 pdf>SEC Complaint<a>,  , <i>https:www sec govlitigationlitreleases2017lr24012 htm<i><br>]
# 1221  [The today announced insider trading charges against a former employee of a semiconductor company and his friend for trading on nonpublic information that the company would be acquired , The SEC alleges that Lanny Brown learned that Infineon Technologies AG planned to acquire his then-employer, International Rectifier Corp   IRC , before the deal was publicly announced According to the SECs complaint, Brown tipped his friend, Sean Fox, about the deal and both of them then acquired IRC call options The SEC further alleges that Brown and Fox concealed Browns involvement in the trading by depositing approximately $12,000 of their combined funds into Foxs brokerage account, and then used this account to purchase the call options for both of them The SEC also alleges that Fox closed out the option positions after the acquisition was publicly announced, and the two defendants made $369,720 in illicit profits To further hide Browns role in the trading, Fox allegedly funneled Browns share of the trading profits by paying several of Browns personal expenses and by writing checks to Browns children and stepchildren Brown and his wife then endorsed those checks and used the funds , The SECs complaint, filed in federal court in the District of Arizona, charges Brown and Fox with violating Section 10 b  of the Securities Exchange Act of 1934 and Rule 10b-5 thereunder A criminal action is also pending against both Brown and Fox in the District of Arizona for the same underlying conduct In the SECs action, the defendants have consented to the entry of a final judgment that permanently enjoins them from future violations of the charged provisions of the federal securities laws The final judgment in the SECs action also orders them to pay, on a joint and several basis, disgorgement of $369,720 plus prejudgment interest of $43,147 79, with a credit for the monetary amount they have agreed to pay in the parallel criminal case against them , The settlements with the SEC are subject to court approval , The SECs investigation was conducted by Yolanda Ochoa and supervised by Finola H  Manvelian of the Los Angeles office The SEC appreciates the assistance of the Financial Industry Regulatory Authority , <p classcenter>###, <img alt border0 height9 srcimagesarrowright_dkblue gif width10><a hreflitigationcomplaints2017comp24015 pdf>SEC Complaint<a>,  , <i>https:www sec govlitigationlitreleases2017lr24015 htm<i><br>]
#
#       class
# 1220      1
# 1221      1

# %%
## DeepSeek's AI, number is index of litigations to avoid confusion
result_1220 = {
  "NameOfTrader": "Kenneth Peer",
  "Profession": "Seattle-based therapist",
  "CompanyInvolved": "zulily, Inc (Zulily)",
  "AcquiringCompany": "Liberty Interactive",
  "SourceOfInformation": "Zulily employee (learned during confidential counseling sessions)",
  "DateOfAcquisitionAnnouncement": "17-08-2015",
  "DatesOfIllegalTransactions": ["21-07-2015", "10-08-2015"],
  "TotalAmountInvested": 28000,
  "IllegalProfits": 10000,
  "StockPriceIncrease": "49%",
  "TradingVolumeIncrease": "15 times the average daily trading volume",
  "LegalConsequences": {
    "Disgorgement": 10227.73,
    "Interest": 811.80,
    "Penalty": 10227.73,
    "TotalPayment": 21267.26,
    "Injunction": "Enjoined from further violations of the charged provisions"
  },
  "SECCharges": [
    "Violation of Section 10(b) of the Securities Exchange Act of 1934",
    "Violation of Section 14(e) of the Securities Exchange Act of 1934",
    "Violation of Rule 10b-5",
    "Violation of Rule 14e-3"
  ],
  "SECInvestigators": {
    "Investigator": "Alice Liu Jensen",
    "Supervisor": "Steven D. Buchholz",
    "Unit": "Market Abuse Unit",
    "RegionalOffice": "San Francisco Regional Office"
  },
  "AssistanceProvidedBy": "FINRA"
}

result_1221 = {
  "NamesOfTraders": ["Lanny Brown", "Sean Fox"],
  "RelationToInsider": "Lanny Brown (former employee of International Rectifier Corp)",
  "CompanyInvolved": "International Rectifier Corp (IRC)",
  "AcquiringCompany": "Infineon Technologies AG",
  "DateOfAcquisitionAnnouncement": "Not explicitly stated in the text", #### THIS IS AN ISSUE 
  "DateOfIllegalTransactions": "Not explicitly stated in the text",     #### THIS IS AN ISSUE 
  "IllegalActivity": "Purchased IRC call options using nonpublic information about the acquisition",
  "FundsDepositedForTrading": 12000,
  "IllegalProfits": 369720,
  "PrejudgmentInterest": 43147.79,
  "LegalConsequences": "Permanent injunctions, disgorgement of $369,720, and prejudgment interest",
  "CriminalAction": "Pending in the District of Arizona",
  "SECInvestigators": {
    "Investigator": "Yolanda Ochoa",
    "Supervisor": "Finola H. Manvelian"
  },
  "AssistanceProvidedBy": "Financial Industry Regulatory Authority (FINRA)"
}

# %%
# From the two known datasets with Name Info, attempt to find ["Lanny Brown", "Sean Fox"]
owner_signature = names_data['OWNERSIGNATURENAME'].str.lower().values
reportin_owner = reporting_owner_data['RPTOWNERNAME'].dropna().str.lower().values

# %%
NAME = 'murray' #'Peer Kenneth' # Peer, Kenneth Peer
for st in owner_signature:
    if NAME.lower() in st:
        print(st)

for st in reportin_owner:
    if NAME.lower() in st:
        print(st)
# Out:
# /s/dennis e murray
# /s/margaret a murray
# /s/ murray j. mccabe
# /s/richard j. rubino, attorney-in-fact for murray a. goldberg
# by: michelle novotny for: murray d. rode
# by: michelle novotny for: murray d. rode
# /s/ ryan lawrence as attorney-in-fact for r. michael murray, jr.
# /s/ stephen p. murray
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# donald b. murray
# /s/ christopher g. ferro, attorney in fact to murray j. demo
# martin murray
# cher s. lawrence, attorney-in-fact for mr. murray smith
# /s/ james t. holder, attorney-in-fact for mr. murray
# murray s. levin
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ john s. lamountain as attorney-in-fact for ryan h. murray
# alan murray
# by: jessica carbullido for: michael j. murray
# /s/w patrick murray
# /s/ susan r. coumes, attorney-in-fact for mr. murray
# james e. murray
# jennifer l. panciocco, attorney-in-fact for robert j. murray
# alan murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/ rebecca rivenbark, as attorney-in-fact for alistair murray sinclair
# christina a. holderman, attorney-in-fact for mark a. murray
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# murray w. burns
# murray g. smith
# /s/dennis e murray
# /s/paul j. schulz, attorney in fact for paul murray
# james e. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# by:  michelle s. hickox      attorney in fact for      murray hamilton edwards
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ kathryn murray, as attorney-in-fact for david d. ward
# /s/ michael j. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ christina poler as attorney-in-fact for murray b. low
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ joe culp, attorney-in-fact for mark murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ xiu ming shum as attorney-in-fact for murray r. garnick
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# sally m. cunningham, power of attorney for murray h. wright
# /s/murray stahl
# sally m. cunningham, power of attorney for murray h. wright
# sally m. cunningham, power of attorney for murray h. wright
# /s/ james e. murray
# georgia murray
# /s/ kevin mcmurray
# /s/ suzanne murray, attorney in fact for robin c. kramer
# /s/ michael j. murray
# /s/ suzanne murray, attorney in fact for chirfi guindo
# suzanne murray, attorney in fact for brian s. posner
# /s/ gerald f sopp for charles a murray
# sally m. cunningham, power of attorney for murray h. wright
# /s/ michael j. murray
# /s/ murray w. burns
# /s/ kevin mcmurray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ michael j. murray
# sally m. cunningham, power of attorney for murray h. wright
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# lilian shackelford murray, by attorney-in-fact pam haley
# /s/ kurston p. mcmurray
# /s/ gerald f sopp for charles a murray
# /s/ gerald f sopp for charles a murray
# /s/ gerald f sopp for charles a murray
# /s/ michael j. murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/ gerald f sopp for charles a murray
# by: /s/ robert a. koch for: george c. murray
# /s/ robert a. koch for: george murray
# by:/s/ robert a. koch for: george c. murray
# by: j. bruce hildebrand attorney in fact for murray h. edwards
# /s/ mark r. townsend for stephen m. murray (pursuant to signing authority on file)
# murray h. hutchison
# /s/ jennifer tornow as attorney-in-fact for murray b. low
# /s/ gerald f sopp for charles a murray
# john j. kauchak, poa jason murray, accounting operations supervisor/avp
# janice bolomey, poa jason murray, accounting operations supervisor/avp
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ michael j. murray
# michael j. murray
# john j. kauchak, poa jason murray, accounting operations supervisor/avp
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# janice bolomey, poa jason murray, accounting operations supervisor/avp
# /s/ justin r. salon, as attorney-in-fact for murray r. wise
# by: wendy whitehouse for: steven j. murray
# by:  michelle s. hickox      attorney in fact for      murray hamilton edwards
# wayne courtright, poa jason murray, accounting operations supervisor/avp
# /s/ michael j. murray
# george boyan, poa jason murray, accounting operations supervisor/avp
# david d. dallas, poa jason murray, accounting operations supervisor/avp
# john j. kauchak, poa jason murray, accounting operations supervisor/avp
# janice bolomey, poa jason murray, accounting operations supervisor/avp
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# by: wendy whitehouse for: steven j. murray
# /s/ justin r. salon, as attorney-in-fact for murray r. wise
# /s/ justin r. salon, as attorney-in-fact for murray r. wise
# george boyan, poa jason murray, accounting operations supervisor/avp
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# /s/ michael j. murray
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# /s/ christine murray
# /s/tabitha bailey, as attorney-in-fact for stacy murray
# /s/ michael r. sullivan, attorney-in-fact for mark christopher murray
# /s/  murray e. brasseux
# w. hildebrandt surgner, jr. for murray r. garnick
# w. hildebrandt surgner, jr. for murray r. garnick
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ murray g. flanigan
# /s/ joe culp, attorney-in-fact for mark murray
# /s/ michael r. sullivan, attorney-in-fact for mark christopher murray
# donald e. souders, jr., poa jason murray, accounting operations supervisor/avp
# /s/ kurston patrick mcmurray
# donald e. souders, jr., poa jason murray, accounting operations supervisor/avp
# /s/jennifer w. dickson, attorney-in-fact on behalf of murray e. brasseux
# vincent geraci, poa jason murray, accounting operations supervisor/avp
# by: wendy whitehouse for: steve j. murray
# /s/ murray smith
# /s/ murray g. flanigan
# /s/ roni mamluk, ph.d., attorney-in-fact for murray a. goldberg
# /s/ murray a. goldberg
# /s/ murray a. goldberg
# george boyan, poa jason murray, accounting operations supervisor/avp
# /s/ michael j. murray
# /s/ murray stewart
# /s/ murray stewart
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ ann j. bruder, as attorney-in-fact for stacy murray
# /s/ paul murray heary
# /s/ ann j. bruder, as attorney-in-fact for stacy murray
# aaron tucker, poa jason murray, accounting operations supervisor/avp
# donald e. souders, jr., poa jason murray, accounting operations supervisor/avp
# raj patel, poa jason murray, accounting operations supervisor/avp
# peter e. maricondo, poa jason murray, accounting operations supervisor/avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# robert h. dallas, ii, poa jason murray, accounting operations supervisor/avp
# david d. dallas, poa jason murray, accounting operations supervisor/avp
# wayne courtright, poa jason murray, accounting operations supervisor/avp
# dr. mark brody, poa jason murray, accounting operations supervisor/avp
# /s/ joe culp, attorney-in-fact for mark murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/shelly l. shaw, attorney-in-fact for murray j. demo
# laureen cook, poa jason murray, financial controls analyst
# by:  james r. gordon      attorney in fact for      murray hamilton edwards
# laureen cook, poa jason murray, financial controls analyst
# laureen cook, poa jason murray, financial controls analyst
# /s/ suzanne murray, attorney in fact for robin c. kramer
# /s/ kevin mcmurray
# /s/ suzanne murray, attorney in fact for chirfi guindo
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ michael j. murray
# /s/ jeff mengoli as attorney-in-fact for steven murray
# /s/ jeff mengoli as attorney-in-fact for steven murray
# revolution growth ugp ii, llc; by: /s/ steven murray, operating manager
# revolution growth gp ii, lp; by: revolution growth ugp ii, llc, its general partner; by: /s/ steven murray, operating manager
# revolution growth ii, lp; by: revolution growth gp ii, lp, its general partner; by: revolution growth ugp ii, llc, its general partner; by: /s/ steven murray, operating manager
# /s/ michael j. murray
# /s/ kurston patrick mcmurray
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ eileen murray
# /s/ joe culp, attorney-in-fact for mark f. murray
# /s/ michael j. murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ kevin mcmurray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# murray h. hutchison
# /s/shelly l. shaw, attorney-in-fact for murray j. demo
# /s/ john g. murray
# /s/ john g. murray
# /s/ john g. murray
# /s/ ryan murray
# /s/ eileen murray
# /s/ john g. murray
# /s/ john g. murray
# /s/ john. g. murray
# /s/ ryan h. murray
# by: james r. gordon attorney in fact for murray hamilton edwards
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# by: wendy whitehouse for: steven j. murray
# by:  james r. gordon       attorney in fact for       murray hamilton edwards
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s/ suzanne murray, attorney-in-fact for rachid izzar
# richard g murray, ii
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# suzanne murray, attorney in fact for caroline d. dorsa
# /s/ suzanne murray, attorney in fact for stephen sherwin
# suzanne murray, attorney in fact for eric k. rowinsky
# suzanne murray, attorney in fact for brian s. posner
# suzanne murray, attorney in fact for richard c. mulligan
# suzanne murray, attorney in fact for nancy leaming
# /s/ suzanne murray, attorney in fact for maria c. freire
# suzanne murray, attorney in fact for stelios papadopoulos
# /s/ suzanne murray, attorney in fact for william allen hawkins iii
# /s/ suzanne murray, attorney in fact for jesus b. mantas
# /s/ suzanne murray, attorney in fact for william d. jones
# /s/ joseph douglas lyon, attorney-in-fact joshua m. murray
# /s/ suzanne murray, attorney in fact for robin c. kramer
# /s/shelly l. shaw, attorney-in-fact for murray j. demo
# /s /jeff mengoli, attorney-in-fact for steven j. murray
# james m. murray
# /s/ kevin mcmurray
# /s/ suzanne murray, attorney in fact for michael d. ehlers
# /s/ john g. murray
# john g. murray
# james m. murray
# /s/ john g. murray
# /s/ john g. murray
# james m. murray
# /s/ margaret b. pritchard as attorney-in-fact for ryan h. murray
# james m. murray
# /s/ christine c. murray  by: michael a. carter, atty-in-fact
# james m. murray
# brookfield retail holdings ii sub iii llc by: brookfield asset management private institutional capital adviser us, llc, its managing member /s/ murray goldfarb, managing partner
# brookfield retail holdings warrants llc., by: brookfield asset management private institutional capital adviser us, llc, its managing member /s/ murray goldfarb, managing partner
# brookfield property group llc /s/ murray goldfarb, managing partner
# brookfield asset management private institutional capital adviser us, llc /s/ murray goldfarb, managing partner
# /s/steven j. murray
# james m. murray
# /s/ scott e. murray
# by:  j. bruce hildebrand attorney in fact for murray hamilton edwards
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ john h. murray, john h. murray
# /s/ john h. murray, john h. murray
# /s/ suzanne murray, attorney in fact for ginger gregory
# /s/ christine c. murray  by: michael a. carter, atty-in-fact
# brookfield property group llc, /s/ murray goldfarb, managing partner
# brookfield asset management private institutional capital adviser us, llc, /s/ murray goldfarb, managing partner
# brookfield retail holdings ii sub iii llc, by: brookfield asset management private institutional capital adviser, us, llc, its managing member, /s/ murray goldfarb, managing partner
# brookfield retail holdings warrants llc, by: brookfield asset management private institutional capital adviser, us, llc, its managing member, /s/ murray goldfarb, managing partner
# /s/ zachariah miller as attorney-in-fact for brad murray
# /s/ gerald f sopp for charles a murray
# /s/  murray e. brasseux
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ suzanne murray, attorney in fact for daniel karp
# /s/ christine c. murray  by: michael a. carter, atty-in-fact
# /s/ christine c. murray  by: michael a. carter, atty-in-fact
# murray h. hutchison
# /s/ john g. murray
# /s/ john g. murray
# /s/ murray smith
# /s/ john g. murray
# /s/ john g. murray
# /s/ sarah a. mussetter as attorney-in-fact for ryan murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ sarah a. mussetter, as attorney-in-fact for ryan murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ joe culp, attorney-in-fact for mark murray
# james davies, poa jason murray, accounting operations supervisor, avp
# james davies, poa jason murray, accounting operations supervisor, avp
# cindi cook on behalf of murray w. burns, pursuant to a power of attorney.
# by: /s/ lauren elkerson for: donald murray
# by: /s/ lauren elkerson for: donald murray
# stephen f. rooney, poa jason murray, accounting operations supervisor, avp
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/robert n. feldman, attorney-in-fact for murray j. demo
# /s/ michael j. murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ michael j. murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# george boyan, poa jason murray, accounting operations supervisor/avp
# /s/ michael r. sullivan, attorney-in-fact for mark christopher murray
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/  murray e. brasseux
# w. hildebrandt surgner, jr. for murray r. garnick
# /s/ michael r. sullivan, attorney-in-fact for mark christopher murray
# /s/ michael r. sullivan, attorney-in-fact for mark christopher murray
# /s/ alan k. tse, attorney-in-fact for neil d. murray
# /s/ murray bailey
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/jennifer w. dickson, attorney-in-fact on behalf of murray e. brasseux
# /s/ murray smith
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# vincent geraci, poa jason murray, accounting operations supervisor/avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# /s/ stewart murray lee
# /s/ stewart murray lee
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# robert h. dallas, ii, poa jason murray, accounting operations supervisor/avp
# david d. dallas, poa jason murray, accounting operations supervisor/avp
# wayne courtright, poa jason murray, accounting operations supervisor/avp
# dr. mark brody, poa jason murray, accounting operations supervisor/avp
# aaron tucker, poa jason murray, accounting operations supervisor/avp
# donald e. souders, jr., poa jason murray, accounting operations supervisor/avp
# raj patel, poa jason murray, accounting operations supervisor/avp
# peter e. maricondo, poa jason murray, accounting operations supervisor/avp
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# /s/ lauren welsh as attorney-in-fact for murray b. low
# minsu kim, poa jason murray, accounting operations supervisor/avp
# david bove, poa jason murray, accounting operations supervisor/vp
# vincent geraci, poa jason murray, accounting operations supervisor/avp
# raj patel, poa jason murray, accounting operations supervisor/avp
# james davies, poa jason murray, accounting operations supervisor, avp
# daniel sharabba, poa jason murray, accounting operations supervisor/avp
# james j. donovan, poa jason murray, accounting operations supervisor/avp
# cher s. lawrence, attorney-in-fact for mr. murray d. smith
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# suzanne murray, attorney in fact for jean-paul kress
# by: vanessa pon for: murray rode
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# suzanne murray, attorney in fact for brian s. posner
# suzanne murray, attorney in fact for eric k. rowinsky
# suzanne murray, attorney in fact for caroline d. dorsa
# suzanne murray, attorney in fact for richard c. mulligan
# suzanne murray, attorney in fact for stephen a. sherwin
# suzanne murray, attorney in fact for stelios papadopoulos
# suzanne murray, attorney in fact for robert w. pangia
# suzanne murray, attorney in fact for nancy leaming
# suzanne murray, attorney in fact for brian s. posner
# suzanne murray, attorney in fact for lynn schenk
# suzanne murray, attorney in fact for alexander j. denner
# /s/ richard j. rubino, attorney-in-fact for murray a. goldberg
# suzanne murray, attorney in fact for michael d. ehlers
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/dennis e murray jr
# /s/steven j. murray
# /s/ kurston mcmurray
# /s/ susan r. coumes, attorney-in-fact for mr. murray
# by: j. bruce hildebrand     attorney in fact for     murray hamilton edwards
# sally m. cunningham, power of attorney for murray h. wright
# murray wright by aric spitulnik by power of attorney
# cher s. lawrence, attorney-in-fact for murray d. smith
# /s/margaret a murray
# /s/ james m. murray
# georgia murray
# /s/dennis e murray jr
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/dennis e murray jr
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# suzanne murray, attorney in fact for michel vounatsos
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# suzanne murray, attorney in fact for michel vounatsos
# grey b murray
# /s/ murray j. mccabe
# suzanne murray, attorney in fact for alexander j. denner
# cindi cook on behalf of murray w. burns, pursuant to a power of attorney.
# suzanne murray, attorney in fact for paul clancy
# by:  j. bruce hildebrand      attorney in fact for       murray hamilton edwards
# stacy murray
# /s/ robert edward murray
# murray h. hutchison
# /s/ gerald f sopp for charles a murray
# /s/ bruce cousins as attorney-in-fact for mark j.murray
# jeff d. barlow, by power of attorney for frank e. murray, m.d.
# suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ karen murray
# /s/ karen murray
# james e. murray
# /s/ murray w. hitzman
# /s/ steve murray
# /s/ steve murray
# /s/ stephen murray
# /s/ michael p. rouvina as attorney-in-fact for r. michael murray, jr.
# by: arleen quinones for: murray n. wright
# /s/ michael p. rouvina as attorney-in-fact for r. michael murray, jr.
# /s/ michael p. rouvina as attorney-in-fact for r. michael murray, jr.
# adam holland, as attorney in fact for murray spain
# /s/ timothy m murray
# antonio g. gomes, attorney-in-fact for murray j. demo
# by: arleen quinones for: murray n. wright
# james e. murray
# /s/louis c. mcmurray
# donald b. murray
# /s/ susan r. coumes, attorney-in-fact for mr. murray
# /s/ james t. holder, attorney-in-fact for james k. murray
# /s/**murray a. goldberg
# /s/**murray a. goldberg
# cher s. lawrence, attorney-in-fact for mr. murray smith
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# jeff d. barlow, by power of attorney for frank e. murray, m.d.
# william a. murray
# jennifer l. panciocco, attorney-in-fact for robert j. murray
# by: jessica carbullido for: michael j. murray
# /s/ rebecca rivenbark, as attorney-in-fact for alistair murray sinclair
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# alan murray
# /s/ stephen murray
# jeff d. barlow, by power of attorney for frank e. murray, m.d.
# christina a. holderman, attorney-in-fact for mark a. murray
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# cheryl c. carter, power of attorney for murray h. wright
# /s/dennis e murray
# /s/ suzanne murray
# /s/ edward c. normandin, esq., attorney-in-fact for murray edward bleach
# /s/paul j. schulz, attorney in fact for paul murray
# /s/ lisa bereda for stephen m murray as attorney in fact
# james e. murray
# derval murray
# cindi cook on behalf of murray w. burns, pursuant to a power of attorney.
# derval murray
# /s/shelly l. shaw, attorney-in-fact for murray j. demo
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# by: wendy whitehouse for: steven j. murray
# by: /s/ jonathan duskin as attorney-in-fact for cynthia murray
# /s/ michael j. murray
# /s/ michael j. murray
# by: wendy whitehouse for: steven j. murray
# /s/ suzanne murray, attorney in fact for stephen sherwin
# /s/ louis c. mcmurray
# /s/  murray e. brasseux
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# /s/ michael j. murray
# /s/ james murray
# /s/ kurston p. mcmurray
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# /s/ louis c. mcmurray
# w. hildebrandt surgner, jr. for murray r. garnick
# /s/ scott e. murray
# /s/wendi s. bickett, attorney-in-fact on behalf of murray e. brasseux
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ suzanne murray, attorney in fact for alphonse galdes
# /s/ suzanne murray, attorney in fact for susan alexander
# /s/ michael j. murray
# by: wendy whitehouse for: steven j. murray
# /s/ suzanne murray, attorney in fact for robin c. kramer
# /s/ suzanne murray, attorney in fact for daniel karp
# /s/ suzanne murray, attorney in fact for chirfi guindo
# /s/ suzanne murray, attorney in fact for ginger gregory
# /s/ suzanne murray, attorney in fact for alphonse galdes
# /s/ suzanne murray, attorney in fact for jeffrey capello
# /s/ suzanne murray, attorney in fact for susan alexander
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ scott e. murray
# /s/ scott e. murray
# /s/ michael j. murray
# /s/ kurston p. mcmurray
# w. hildebrandt surgner, jr. for murray r. garnick
# by:  j. bruce hildebrand      attorney in fact for       murray hamilton edwards
# /s/ suzanne murray, attorney in fact for stephen sherwin
# /s/ seth rasmussen, as attorney-in-fact for stacy murray
# /s/ robert a. koch for: george murray
# /s/ ann j. bruder, as attorney-in-fact for stacy murray
# /s/ kevin mcmurray
# /s/ suzanne murray, attorney in fact for jeffrey capello
# /s/ james e. murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ kevin mcmurray
# murray h. hutchison
# amy y. murray by:  karl j. grafe, as attorney-in-fact
# david bove, poa jason murray, accounting operations supervisor/vp
# raj patel, poa jason murray, accounting operations supervisor/avp
# /s/ michael j. murray
# amy y. murray by: joseph c. alter, as attorney-in-fact
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ murray g. flanigan
# vincent geraci, poa jason murray, accounting operations supervisor/avp
# minsu kim, poa jason murray, accounting operations supervisor/avp
# vincent geraci, poa jason murray, accounting operations supervisor/avp
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# mary e. gross, poa jason murray, accounting operations supervisor/avp
# /s/ tabitha t. bailey, as attorney-in-fact for stacy murray
# /s/ michael j. murray
# s/ kurston p. mcmurray
# /s/ michael j. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ michael j. murray
# w. hildebrandt surgner, jr. for murray r. garnick
# by:  michelle s. hickox      attorney in fact for      murray hamilton edwards
# james a. hughes, poa jason murray, accounting operations supervisor, avp
# /s/ lauren welsh as attorney-in-fact for murray b. low
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ karen murray
# /s/ scott e. murray
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# suzanne murray, attorney in fact for robert w. pangia
# by: wendy whitehouse for: steven j. murray
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# sally m. cunningham, power of attorney for murray h. wright
# by: wendy whitehouse for: steven j. murray
# /s/murray stahl
# /s/murray stahl
# sally m. cunningham, power of attorney for murray h. wright
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/ michael j. murray
# /s/ victor torres, attorney-in-fact for mr. murray kessler.
# /s/ michael j. murray
# /s/ mark j. murray
# /s/ suzanne murray, attorney in fact for paul mckenzie
# /s/ scott e. murray
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# /s/ gerald f sopp for charles a murray
# w. hildebrandt surgner, jr. for murray r. garnick
# /s/ anna szygorski as attorney-in-fact for murray b. low
# /s/ suzanne murray, attorney in fact for susan alexander
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ scott e. murray
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ suzanne murray, attorney in fact for paul mckenzie
# /s/ suzanne murray, attorney in fact for michael d. ehlers
# /s/ suzanne murray, attorney in fact for susan alexander
# /s/ michael j. murray
# suzanne murray, attorney in fact for brian s. posner
# /s/ hunter s. smith as attorney-in-fact for murray stewart
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ suzanne murray, attorney in fact for alfred w. sandrock, jr.
# /s/ suzanne murray, attorney in fact for paul mckenzie
# /s/ suzanne murray, attorney in fact for robin c. kramer
# /s/ suzanne murray, attorney in fact for daniel karp
# /s/ suzanne murray, attorney in fact for chirfi guindo
# /s/ suzanne murray, attorney in fact for ginger gregory
# /s/ suzanne murray, attorney in fact for michael d. ehlers
# /s/ suzanne murray, attorney in fact for jeffrey capello
# /s/ suzanne murray, attorney in fact for susan alexander
# /s/ michael j. murray
# /s/ kurston p. mcmurray
# /s/wendi s. bickett, attorney-in-fact on behalf of murray e. brasseux
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# w. hildebrandt surgner, jr. for murray r. garnick
# by: wendy whitehouse for: steven j. murray
# /s/ george murray
# /s/dennis e murray jr
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# by: /s/ michelle gouvion for: donald murray
# sally m. cunningham, power of attorney for murray h. wright
# /s/ kevin mcmurray
# /s/ murray c. gardner
# /s/wendi s. bickett, attorney-in-fact on behalf of murray e. brasseux
# /s/ murray t. holland
# /s/ suzanne murray, attorney in fact for jeffrey capello
# /s/ gerald f sopp for charles a murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ murray l. skala
# murray h. hutchison
# /s/ christine c. murray  by: george r. mckown, iii, atty-in-fact
# /s/ murray g. flanigan
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# /s/ suzanne murray, attorney in fact for jesus b. mantas
# /s/ suzanne murray, attorney in fact for william allen hawkins iii
# /s/ suzanne murray, attorney in fact for stephen sherwin
# suzanne murray, attorney in fact for lynn schenk
# suzanne murray, attorney in fact for eric k. rowinsky
# suzanne murray, attorney in fact for brian s. posner
# suzanne murray, attorney in fact for stelios papadopoulos
# suzanne murray, attorney in fact for robert w. pangia
# suzanne murray, attorney in fact for richard c. mulligan
# suzanne murray, attorney in fact for nancy leaming
# suzanne murray, attorney in fact for caroline d. dorsa
# /s/ suzanne murray, attorney in fact for jesus b. mantas
# /s/ suzanne murray, attorney in fact for william allen hawkins iii
# /s/ wendy walton, as attorney-in-fact for stacy murray
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/ john g. murray
# /s/ dov bergwerk as attorney-in-fact for murray a. goldberg
# /s/ mackenzie k. phillips attorney-in-fact for neil d. murray
# /s/ mackenzie k. phillips attorney-in-fact for neil d. murray
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/  murray e. brasseux
# lilian shackelford murray, by attorney-in-fact, sheila khayami
# /s/ suzanne murray, attorney in fact for michael d. ehlers
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# /s/ john g. murray
# /s/ john larocca, attorney-in-fact for murray a. goldberg
# /s/ murray gardner
# /s/ louis c. mcmurray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# murray wright by aric spitulnik by power of attorney
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/  murray e. brasseux
# /s/ murray j. mccabe
# /s/ suzanne murray, attorney in fact for michel vounatsos
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# grey b murray
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# /s/ christine c. murray  by:  george r. mckown, atty-in-fact
# /s/ karen murray
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# murray h. hutchison
# /s/ gerald f sopp for charles a murray
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# /s/ stephen murray
# by: arleen quinones for: murray n. wright
# by: arleen quinones for: murray n. wright
# /s/ theresa murray, attorney-in-fact for david c. hisey
# /s/ theresa murray, attorney-in-fact for robert l. appel
# /s/ theresa murray, attorney-in-fact for harold lewis
# /s/ theresa murray, attorney-in-fact for jesse k. bray
# /s/ theresa murray, attorney-in-fact for amar r. patel
# /s/ theresa murray, attorney-in-fact for lisa a. rogers
# /s/ theresa murray, attorney-in-fact for anthony w. villani
# /s/ theresa murray, attorney-in-fact for ramesh lakshminarayanan
# /s/ theresa murray, attorney-in-fact for douglas krueger
# cher s. lawrence, attorney-in-fact for murray d. smith
# murray s. levin
# /s/ theresa murray, attorney-in-fact for douglas krueger
# /s/ theresa murray, attorney-in-fact for lisa a. rogers
# /s/ theresa murray, attorney-in-fact for harold lewis
# /s/ theresa murray, attorney-in-fact for anthony w. villani
# /s/ theresa murray, attorney-in-fact for jesse k. bray
# /s/ theresa murray, attorney-in-fact for david c. hisey
# murray s. levin
# r. patrick murray, ii, as attorney-in-fact
# william a. murray
# james w. murray, iii
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# w. murray rodgers
# /s/ w. murray rodgers
# /s/ murray jones
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# by: laura malinasky, attorney-in-fact  for: murray d. rode
# christina a. holderman, attorney-in-fact for mark a. murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/ stephen murray
# ccmp capital, llc,  /s/ stephen p. murray, president & ceo
# ccmp capital associates gp, llc, /s/ stephen p. murray, president & ceo
# ccmp capital associates, l.p., /s/ stephen p. murray, president & ceo
# ccmp generac co-invest gp, llc,  /s/ stephen p. murray, president & ceo
# ccmp generac co-invest, l.p., /s/ stephen p. murray, president & ceo
# ccmp capital investors ii, l.p., /s/ stephen p. murray, president & ceo
# ccmp capital investors (cayman) ii, l.p., /s/ stephen p. murray, president & ceo
# james e. murray
# /s/ james t. holder, attorney-in-fact for james k. murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# by jess jankowski, under upa, for patrick g. murray
# /s/ harry m. murray
# by: laura malinasky, attorney-in-fact  for: murray d. rode
# /s/ harry m. murray
# /s/ christopher ferro, attorney in fact to murray j. demo
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ ronald s. milstein, attorney-in-fact for murray s. kessler
# jean jacob - poa for murray martin
# jean jacob - poa for murray martin
# by: laura malinasky, attorney-in-fact  for: murray d. rode
# christina a. holderman, attorney-in-fact for mark a. murray
# /s/ george f. murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ harry m. murray
# by: laura malinasky, attorney-in-fact  for: murray d. rode
# /s/**murray a. goldberg
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/ murray l. skala
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ tom garcia for stephen m. murray as attorney in fact
# norman c. linnell, attorney-in-fact for charles j. mcmurray
# /s/paul j. schulz, attorney in fact for paul murray
# james e. murray
# /s/paul j. schulz, attorney in fact for paul murray
# /s/shelly l. shaw, attorney-in-fact for murray j. demo
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ john g. murray
# /s/ suzanne murray, attorney in fact for stephen sherwin
# suzanne murray, attorney in fact for eric k. rowinsky
# suzanne murray, attorney in fact for brian s. posner
# suzanne murray, attorney in fact for stelios papadopoulos
# suzanne murray, attorney in fact for robert w. pangia
# suzanne murray, attorney in fact for richard c. mulligan
# /s/ suzanne murray, attorney in fact for jesus b. mantas
# suzanne murray, attorney in fact for nancy leaming
# /s/ suzanne murray, attorney in fact for william allen hawkins iii
# suzanne murray, attorney in fact for caroline d. dorsa
# georgia murray
# lilian shackelford murray, by attorney-in-fact, summer howard
# /s/ john g. murray
# /s/  murray e. brasseux
# /s/ louis c. mcmurray
# /s/ mark r. townsend for stephen m. murray (pursuant to signing authority on file)
# /s/ john larocca, attorney-in-fact for murray a. goldberg
# /s/ james e. murray
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# /s/ roni mamluk, attorney-in-fact for murray goldberg
# grey b. murray
# /s/ murray j. mccabe
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# /s/ christine c. murray  by: george r. mckown, atty-in-fact
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# murray h. hutchison
# /s/ kevin mcmurray
# /s/ mark r. townsend for stephen m. murray (pursuant to signing authority on file)
# /s/ murray j. mccabe
# /s/ mark j. murray
# william h. gault, attorney-in-fact for mr. murray smith
# /s/ stephen murray
# /s/ stephen murray
# /s/**murray a. goldberg
# by: j. bruce hildebrand     attorney in fact for     murray hamilton edwards
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# by: j. bruce hildebrand attorney in fact for murray hamilton edwards
# /s/ michael j. murray
# by: william r. hughes, attorney-in-fact for: murray d. rode
# james e. murray
# /s/dennis e murray
# cheryl c. carter, power of attorney for murray h. wright
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/ michael j. murray
# /s/ james t. holder, attorney-in-fact for james k murray
# lily j. lu, attorney-in-fact for robert j. murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ jason a. duva as attorney-in-fact for ryan h. murray
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# jeff d. barlow, by power of attorney for frank e. murray, m.d.
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# christina a. holderman, attorney-in-fact for mark a. murray
# cindi cook on behalf of murray w. burns, pursuant to a power of attorney.
# /s/**murray a. goldberg
# /s/ alan murray
# /s/ michael j. murray
# donald b. murray
# murray h. hutchison
# jeff d. barlow, by power of attorney for frank e. murray, m.d.
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# /s/paul j. schulz, attorney in fact for paul murray
# cher s. lawrence, attorney-in-fact for mr. murray smith
# james e. murray
# amy y. murray by:  joseph c. alter, as attorney-in-fact
# /s/ joe culp, attorney-in-fact for mark murray
# /s/ ryan brown as attorney-in-fact for dallan murray
# /s/ ryan morgan, as attorney-in-fact for murray r. garnick
# /s/ john g. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ katy murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# amy y. murray by:  joseph c. alter, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ georgia murray
# /s/ teri l. witteman, as attorney-in-fact for joshua m. murray
# /s/ teri l. witteman, as attorney-in-fact for joshua m. murray
# /s/ joseph douglas lyon, as attorney-in-fact for joshua m. murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ murray smith
# /s/ michael j. murray
# by:  michelle s. hickox       attorney in fact for       murray hamilton edwards
# /s/ ryan brown as attorney-in-fact for dallan murray
# /s/ ryan brown as attorney-in-fact for dallan murray
# /s/ murray j. mccabe
# /s/ murray g. flanigan
# /s/ suzanne murray, as attorney-in-fact
# by:  michelle s. hickox       attorney in fact for       murray hamilton edwards
# /s/ john f. henry, jr., by power of attorney for hilda s. murray
# by:  michelle s. hickox      attorney in fact for       murray hamilton edwards
# /s/ brian murray, by kristi maher, attorney-in-fact, pursuant to a power of attorney
# /s/ michael j. murray
# /s/ michael j. murray
# /s/ paul murray heary
# /s/ suzanne murray, as attorney-in-fact
# /s/ alan k. tse, attorney-in-fact for neil d. murray
# /s/ eileen k murray
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ suzanne murray, as attorney-in-fact
# /s/ alan k. tse, attorney-in-fact for neil d. murray
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# murray energy holdings co. /s/ robert e. murray by: robert e. murray title: president and chief executive officer
# murray energy corporation /s/ robert e. murray by: robert e. murray title: president and chief executive officer
# /s/ robert e. murray
# robert e. murray trust /s/ robert e. murray by: robert e. murray title: settlor and trustee
# cher s. lawrence, attorney-in-fact for mr. murray d. smith
# /s/dennis e murray jr
# james e. murray
# /s/ robin e. murray
# by: wendy whitehouse for: steven j. murray
# suzanne murray, attorney in fact for paul clancy
# by: wendy whitehouse for: steven j. murray
# /s/ michael j. murray
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv, by power of attorney
# /s/ richard murray, iv
# /s/ richard murray, iv, by power of attorney
# /s/steven j. murray
# r. patrick murray, ii, as attorney-in-fact
# /s/ michael j. murray
# james e. murray
# robert e. murray /s/ robert e. murray
# murray energy corporation /s/ robert e. murray by: robert e. murray title: president and chief executive officer
# murray energy holdings co. /s/ robert e. murray by: robert e. murray title: president and chief executive officer
# robert e. murray trust /s/ robert e. murray by: robert e. murray title: settlor and trustee
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# valerie o. murray
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# r. patrick murray, ii, as attorney-in-fact
# /s/ charlotte sim-warner as attorney-in-fact for murray b. low
# /s/dennis e murray jr
# james e. murray
# suzanne murray, attorney in fact for susan alexander
# suzanne murray, attorney in fact for alfred w. sandrock, jr.
# suzanne murray, attorney in fact for michel vounatsos
# suzanne murray, attorney in fact for paul clancy
# suzanne murray, attorney in fact for adriana karaboutis
# suzanne murray, attorney in fact for gregory f. covino
# suzanne murray, attorney in fact for michael d. ehlers
# joseph michael murray by joseph b. wollard, attorney-in-fact
# /s/ scott e. murray
# /s/ alessandra melloni as attorney-in-fact for ryan h. murray
# /s/ kevin tang, attorney-in-fact for alan s. murray
# /s/ murray williams
# /s/ michael j. murray
# by: wendy whitehouse for: steven j. murray
# /s/ kevin tang, attorney-in-fact for alan s. murray
# /s/margaret a murray
# /s/dennis e murray jr
# /s/ louis c. mcmurray
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# grey b murray
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# /s/antonio g gomes, attorney-in-fact for murray j. demo
# by:  j. bruce hildebrand      attorney in fact for      murray hamilton edwards
# joseph michael murray by joseph b. wollard, attorney-in-fact
# /s/george murray
# ...
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# brasseux murray e
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray christopher m
# murray richard /ca/
# stahl murray
# murray dennis e jr
# stahl murray
# stahl murray
# mcmurray bill
# murray stacy
# murray william l.
# bryan murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray richard iv
# murray james chadwick
# mcmurray bill
# bryan murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray christopher m
# stahl murray
# stahl murray
# murray richard /ca/
# murray william l.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray richard /ca/
# murray novelette
# stahl murray
# stahl murray
# murray neil
# stahl murray
# stahl murray
# murray mark christopher
# stahl murray
# stahl murray
# stahl murray
# obrien thomas murray
# murray steven joseph
# stahl murray
# stahl murray
# murray stacy
# stahl murray
# stahl murray
# stahl murray
# murray richard /ca/
# stahl murray
# stahl murray
# murray christopher m
# murray stacy
# mcmurray kevin
# murray mark a
# stahl murray
# low murray b
# murray novelette
# murray james e
# hutchison murray h
# obrien thomas murray
# mcmurray kevin
# murray robin p.
# murray thomas a.
# murray mark a
# stahl murray
# stahl murray
# gell-mann murray
# mcmurray charles j
# cohen murray s
# murray michael q
# murray harry m
# wright murray n
# murray timothy m
# robinson murray o.
# mcmurray mike k
# mcmurray charles j
# demo murray j
# edwards murray hamilton
# wright murray n
# martin murray d
# murraymetzger elias arthur
# spain murray
# murray stephen m
# demo murray j
# bleach murray e
# demo murray j
# demo murray j
# murray robert j
# mcmurray charles j
# edwards murray hamilton
# simser murray
# murray michael john
# martin murray d
# martin murray d
# murray robert j
# murray james k
# goldberg murray a
# murray patrick m
# murray james k
# smith murray d
# murray richard patrick ii
# demo murray j
# edwards murray hamilton
# murray robert j
# edwards murray hamilton
# demo murray j
# demo murray j
# demo murray j
# murray robert c
# murray christopher m
# smith richard murray
# demo murray j
# murray michael john
# murray robert j
# murray alan
# mcmurray charles j
# murray mark a
# murray mark a
# murray mark a
# murray mark a
# rode murray d
# murray suzanne e
# goldberg murray a
# murray frank e md
# murray michael john
# edgen murray ii, l.p.
# murray timothy
# murray mark a
# murray hilda s
# obrien thomas murray
# wright murray h
# mcmurray charles j
# murray timothy
# murray stephen
# murray stephen m
# murray michael q
# murray james e
# mcmurray charles j
# smith richard murray
# murray paul
# murray christopher m
# murray sandra
# murray james e
# wright murray n
# demo murray j
# smith murray d
# murray mark j.
# murray george
# murray ryan h
# rode murray d
# goldberg murray a
# demo murray j
# alan murray j.
# murray steven joseph
# spain murray
# murray alan
# murray robert j
# murray richard patrick ii
# smith murray d
# murray dennis e jr
# burns murray w.
# low murray b
# murray alan
# murray dennis e jr
# murray alan
# murray michael john
# murray ryan h
# murray ryan h
# murray richard patrick ii
# murray james michael
# murray michael john
# gardner murray c
# wright murray h
# kessler murray s
# kessler murray s
# murray hilda s
# obrien thomas murray
# demo murray j
# murray bill
# murray michael j
# murray mark a
# mccabe murray j.
# mccabe murray j.
# mcmurray sean patrick
# murray bill
# murray george
# murray bill
# murray ryan h
# edwards murray hamilton
# murray alan
# murray george
# murray richard patrick ii
# murray bill
# murray george f
# murray richard patrick ii
# murray frank e md
# mcmurray steven r
# mccabe murray j.
# kessler murray s
# murray paul
# murray james e
# hutchison murray h
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray andrew j.
# stahl murray
# stahl murray
# stahl murray
# murray james chadwick
# stahl murray
# stahl murray
# demo murray j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# murray steven joseph
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# mccabe murray j.
# murray novelette
# stahl murray
# stahl murray
# murray blake thomas
# stahl murray
# stahl murray
# murray richard iv
# stahl murray
# stahl murray
# murray blake thomas
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# murray andrew j.
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray blake thomas
# murray blake thomas
# stahl murray
# stahl murray
# wise murray r
# wise murray r
# stahl murray
# stahl murray
# murray james chadwick
# murray neil
# stahl murray
# stahl murray
# murray steven joseph
# edwards murray hamilton
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# mcmurray kurston patrick
# murray james chadwick
# stahl murray
# stahl murray
# low murray b
# mcmurray kurston patrick
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray amy y
# stahl murray
# stahl murray
# mcmurray michael c.
# stahl murray
# stahl murray
# low murray b
# stahl murray
# stahl murray
# murray andrew j.
# stahl murray
# stahl murray
# murray steven joseph
# stahl murray
# stahl murray
# grainger murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray andrew j.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# murray stephen m
# stahl murray
# stahl murray
# rode murray d
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray neil
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray novelette
# stahl murray
# stahl murray
# murray andrew j.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray john g.
# stahl murray
# stahl murray
# murray neil
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray andrew j.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# murray novelette
# stahl murray
# stahl murray
# low murray b
# stahl murray
# stahl murray
# rode murray d
# murray james e
# murray william patrick
# gross murray h
# mcmurray charles j
# murray timothy m
# fleming murray
# murray christopher m
# murray michael q
# murray dennis j
# murray dennis j
# wright murray n
# murray christopher m
# spain murray
# mcmurray charles j
# demo murray j
# wright murray n
# murraymetzger elias arthur
# demo murray j
# martin murray d
# murray christopher m
# murray john e
# mcmurray charles j
# murray robert j
# murray terrence
# murray margaret a
# murray patrick m
# murray margaret a
# murray michael john
# murray james e
# murray james k
# rode murray d
# dashe murray h
# demo murray j
# murray robert j
# demo murray j
# murray richard patrick ii
# murray michael john
# gell-mann murray
# murray alan
# murray terrence
# murray robert j
# mcmurray charles j
# murray james k
# murray sandra
# brennan murray
# rode murray d
# murray robert c
# obrien thomas murray
# murray patrick g
# wright murray n
# murray robin e
# wright murray h
# murray mark a
# murray paul
# murray frank e md
# mcmurray charles j
# rode murray d
# murray timothy m
# rode murray d
# rode murray d
# murray michael q
# mcmurray stephen d
# mcmurray charles j
# mcmurray mike k
# brean murray carret group inc.
# brean murray carret group inc.
# mcmurray stephen d
# murray michael anthony
# smith richard murray
# murray williams h
# murray christopher m
# murray james e
# kessler murray s
# murray neil
# demo murray j
# murray richard iv
# wright murray h
# murray george c
# burns murray w.
# murray patrick m
# murray john g.
# murray ryan h
# murray mary k
# murray michael j
# murray brad
# murray christine c
# murray john g.
# murray james michael
# murray mark j.
# mcmurray kevin
# murray neil
# murray michael j
# murray james michael
# mcmurray kurston patrick
# murray james michael
# mcmurray kurston patrick
# murray michael j
# kessler murray s
# murray steven joseph
# murray james michael
# murray michael j
# mcmurray michael c.
# murray james michael
# murray christine c
# burns murray w.
# murray james michael
# garnick murray r
# murray neil
# murray james michael
# stewart murray
# stewart murray
# obrien thomas murray
# murray james michael
# murray jerry j
# forbes murray iii
# kessler murray s
# kessler murray s
# mcmurray michael c.
# hutchison murray h
# murray james michael
# low murray b
# murray alex
# murray christine c
# murray charles a
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# murray george f
# stahl murray
# stahl murray
# murray brian l
# murray brian l
# murray brian l
# murray brian l
# murray brian l
# murray brian l
# murray brian l
# murray brian l
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray steven j
# murray neil d
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# murray steven j
# murray christine
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray michael j
# kessler murray s
# murray christopher k.
# stahl murray
# stahl murray
# murray valerie o
# murray eileen k
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray valerie o
# murray christopher k.
# murray mark f.
# stahl murray
# stahl murray
# low murray b
# brasseux murray e
# garnick murray r
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# forbes murray iii
# garnick murray r
# stahl murray
# stahl murray
# mcmurray michael c.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# mcmurray bill
# murray thomas a.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray william l.
# stahl murray
# murray martin
# stahl murray
# stahl murray
# murray steven joseph
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# stahl murray
# stahl murray
# mcmurray kurston patrick
# stahl murray
# stahl murray
# murray dennis e jr
# stahl murray
# stahl murray
# murray benjamin joseph
# murray benjamin joseph
# murray benjamin joseph
# murray benjamin joseph
# murray benjamin joseph
# murray benjamin joseph
# murray benjamin joseph
# brasseux murray e
# flanigan murray guinn
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# mcmurray bill
# murray richard /ca/
# murray william l.
# mcmurray bill
# stahl murray
# stahl murray
# stahl murray
# bryan murray
# edwards murray hamilton
# stahl murray
# stahl murray
# stahl murray
# flanigan murray guinn
# murray william l.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray richard iv
# stahl murray
# stahl murray
# murray mark christopher
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray novelette
# stahl murray
# stahl murray
# murray richard /ca/
# murray stacy
# stahl murray
# stahl murray
# murray donald b
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray thomas a.
# stahl murray
# stahl murray
# murray stacy
# murray thomas a.
# murray novelette
# stahl murray
# stahl murray
# murray james e
# stahl murray
# stahl murray
# stahl murray
# murray mark a
# stahl murray
# lee murray
# stahl murray
# stahl murray
# murray richard iv
# mccabe murray j.
# murray steven joseph
# spain murray
# murray steven joseph
# mccabe murray j.
# kessler murray s
# kessler murray s
# kessler murray s
# rode murray d
# murray r michael jr
# spain murray
# brennan murray
# demo murray j
# demo murray j
# martin murray d
# demo murray j
# mcmurray louis c
# mcmurray louis c
# murray joseph michael
# smith murray d
# murray cherry a
# demo murray j
# murray james k
# smith murray d
# murray richard patrick ii
# murray michael john
# murray mary o
# murray michael john
# murray alan
# alan murray j.
# murray alan
# alan murray j.
# demo murray j
# martin murray d
# murray robert j
# gross murray h
# fleming murray
# murray robert j
# obrien thomas murray
# murray r michael jr
# edwards murray hamilton
# murray timothy
# murray mark a
# edwards murray hamilton
# murray michael
# murray hilda s
# murray george
# murray ryan h
# murray energy holdings co.
# murray energy corp
# murray robert eugene
# robert e. murray trust
# murray george
# burns murray w.
# mcmurray sean patrick
# murray suzanne e
# murray suzanne e
# murray alan
# goldberg murray a
# murray paul
# murray frank e md
# hutchison murray h
# mccabe murray j.
# murray mark j.
# murray paul
# murray mary k
# demo murray j
# smith murray d
# murray james e
# murray george
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray eileen k
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray john g.
# murray john g.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray john g.
# murray john g.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray stephen h.
# stahl murray
# stahl murray
# murray jason hulse
# stahl murray
# stahl murray
# stahl murray
# murray mark f.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray novelette
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray novelette
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray lilian shackelford
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# mcmurray louis c
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# garnick murray r
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray daniel timothy
# stahl murray
# stahl murray
# stahl murray
# murray steven joseph
# bryan murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# stahl murray
# fitzpatrick alan murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray mark christopher
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray eileen k
# stahl murray
# stahl murray
# stahl murray
# murray kieran t.
# murray kieran t.
# stahl murray
# murray george f
# murray michael andrew
# stahl murray
# mcmurray kevin
# murray john g.
# murray john g.
# murray john g.
# demo murray j
# murray john g.
# murray neil
# murray john g.
# murray john g.
# murray mary o
# skala murray l
# hutchison murray h
# bryan murray
# murray richard iv
# murray brad
# murray christine c
# murray neil
# mcmurray kurston patrick
# flanigan murray guinn
# murray neil
# murray scott e.
# brasseux murray e
# skala murray l
# mcmurray michael c.
# brasseux murray e
# murray christine c
# murray ryan h
# macnaughtan murray david
# bryan murray
# murray neil
# gardner murray c
# wright murray h
# demo murray j
# demo murray j
# murray christine c
# hutchison murray h
# murray charles a
# stahl murray
# mcmurray kevin
# stahl murray
# stahl murray
# demo murray j
# stahl murray
# stahl murray
# murray john g.
# murray john g.
# murray john g.
# stahl murray
# murray neil
# stahl murray
# murray john g.
# murray john g.
# murray novelette
# murray john g.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray mark f.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# low murray b
# stahl murray
# stahl murray
# edwards murray hamilton
# stahl murray
# stahl murray
# mcmurray kevin
# murray elizabeth a.
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray steven j
# stahl murray
# murray neil
# stahl murray
# stahl murray
# murray michael j
# stahl murray
# stahl murray
# murray neil d
# stahl murray
# murray dennis e jr
# murray steven joseph
# stahl murray
# stahl murray
# stahl murray
# murray steven joseph
# brasseux murray e
# stahl murray
# stahl murray
# murray stacy
# stahl murray
# murray steven j
# stahl murray
# low murray b
# stahl murray
# murray steven joseph
# rode murray d
# smith murray george
# smith murray george
# stahl murray
# bryan murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray william l.
# stahl murray
# stahl murray
# murray neil
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# murray lilian shackelford
# stahl murray
# stahl murray
# stahl murray
# stahl murray
# mcmurray kevin
# stahl murray
# hutchison murray h
# low murray b
# stahl murray
# stewart murray
# obrien thomas murray
# demo murray j

# %%
NAME = 'Fox Sean' #'Sean Fox' #'Brown Lanny' #'Lanny Brown'

for st in owner_signature:
    if NAME.lower() in st:
        print(st)

for st in reportin_owner:
    if NAME.lower() in st:
        print(st)

# %% [markdown]
# # Discarded

# %%
# Code after Dary;'s extraction to further clean
names_data_clean = pd.read_csv(f'{DATA_FOLDER}/extracted_names.csv')

names_data_subset = names_data_clean[names_data_clean['ACCESSION_NUMBER'].isin(matching_rpt_names_pk['ACCESSION_NUMBER'])]

import re

def clean_names(name):
    # Remove legal-related terms (case-insensitive)
    name = re.sub(r'(?i)(attorney[-\s]?in[-\s]?fact|power[-\s]?attorney|P\.O\.A\.?|behalf|by )', ',', name)

    # Replace multiple spaces or commas with a single comma for clean splitting
    name = re.sub(r'\s*,\s*', ',', name)  # Clean up commas
    name = re.sub(r'\s+', ' ', name).strip()  # Remove extra spaces

    # Split by comma if necessary and return clean names
    names = [n.strip() for n in name.split(',') if n.strip()]
    return ', '.join(names)

names_data_subset['OWNERSIGNATURENAME_FINAL'] = names_data_subset['extracted'].apply(clean_names)
